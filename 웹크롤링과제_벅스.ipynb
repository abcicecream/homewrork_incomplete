# %%
from bs4 import BeautifulSoup

# %%
# 벅스 웹 크롤링 안되서 글로 가져옴

# %%
html = """자동 줄바꿈
<!DOCTYPE html>
<html lang="ko">
<head>
<!-- bgsweb-www908 -->




<meta charset="utf-8">
<meta http-equiv="X-UA-Compatible" content="IE=edge">
<meta name="keywords" content="노래추천, 음악추천, 플레이리스트, essential, 에센셜, 스트리밍, 스밍, 뮤직PD, 노래듣기, 음악다운로드, 페이코" />
<meta name="viewport" content="width=device-width, initial-scale=1" />

<script type="text/javascript">
if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0
|| location.href.indexOf("help.bugs.co.kr") >= 0))
document.domain = 'bugs.co.kr';

var g_urlBase = "https://www.bugs.co.kr";
var g_urlWww = "https://www.bugs.co.kr";
var g_urlSecure = "https://secure.bugs.co.kr";
var g_urlMusic = "https://music.bugs.co.kr";
var g_urlMusicSecure = "https://music.bugs.co.kr";
var g_urlMember = "https://secure.bugs.co.kr/member";
var g_urlFile = "https://file.bugsm.co.kr/wbugs";
var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
//var g_urlSwf = "https://music.bugs.co.kr/swf";
var g_urlSwf = "https://music.bugs.co.kr/swf";
var g_urlJs = "/js";
var g_urlMe = "https://music.bugs.co.kr/user";
var g_urlThumbnail = "http://nboardr.bugs.co.kr/thumbnail";
var g_urlOpenalbum = "https://music.bugs.co.kr/openalbum";
var g_urlClipimg = "//image.bugsm.co.kr";
//var g_urlLikes = "https://music.bugs.co.kr/like";
//var g_urlPlaylists = "https://music.bugs.co.kr/playlist";
var g_urlLikes = "https://music.bugs.co.kr/like";
var g_urlPlaylists = "https://music.bugs.co.kr/playlist"
var g_urlListen = "https://music.bugs.co.kr/listen";
var g_urlMyinfo = "https://music.bugs.co.kr/myinfo";
var g_urlSecureMyinfo = "https://secure.bugs.co.kr/myinfo";
var g_urlSearch = "https://music.bugs.co.kr/search";
var g_urlChart = "https://music.bugs.co.kr/chart";
var g_urlPay = "https://music.bugs.co.kr/pay";
var g_urlBilling = "https://pay.bugs.co.kr";
var g_urlPartner = "https://www.bugs.co.kr/Partner";
var g_urlSecurePay = "https://secure.bugs.co.kr/pay";
var g_urlOtu = "https://notu.bugs.co.kr";
var g_urlBoard = "http://board.bugs.co.kr/notice";
var g_urlEvent = "https://music.bugs.co.kr/event";
var g_storageServerRead = "http://nboardr.bugs.co.kr";
var g_storageServerWrite = "https://nboardw.bugs.co.kr";
var g_storageServerFileUploadTmp = g_storageServerWrite+"/adminimg/storage/upload";
var g_urlPanel = "https://music.bugs.co.kr/panel";
var g_urlAjax = "https://music.bugs.co.kr";
var g_urlAppsvr = "https://music.bugs.co.kr";
var g_urlMusicPd = "https://music.bugs.co.kr/musicpd";
var g_urlGenre = "https://music.bugs.co.kr/genre";
var g_urlMLounge = "https://mlounge.bugs.co.kr";
var g_urlNinanoclub = "http://ninanoclub.bugs.co.kr";
var g_urlM = "https://m.bugs.co.kr";
var g_urlDl = "https://dl.bugs.co.kr";
var g_urlBGT = "https://bgt.bugs.co.kr";
var g_urlFavorite = "https://favorite.bugs.co.kr";

var g_env = "svc";

var g_isLogged = false;
var g_msrl = false;
var g_isGuest = false;
</script>


<!-- cache.filePacking : true -->

<!-- bugs file packing [ open_lib_js ] cached data / start -->
<script type='text/javascript' src='//music.bugs.co.kr/filepacking/open_lib_js?env=svc&_t_s_=20251206-1255' ></script>
<!-- bugs file packing [ open_lib_js ] cached data / end -->


<!-- bugs file packing [ bugs_desktopLib_js ] cached data / start -->
<script type='text/javascript' src='//music.bugs.co.kr/filepacking/bugs_desktopLib_js?env=svc&_t_s_=20251206-1255' ></script>
<!-- bugs file packing [ bugs_desktopLib_js ] cached data / end -->


<!-- bugs file packing [ bugs_newLib_js ] cached data / start -->
<script type='text/javascript' src='//music.bugs.co.kr/filepacking/bugs_newLib_js?env=svc&_t_s_=20251206-1255' ></script>
<!-- bugs file packing [ bugs_newLib_js ] cached data / end -->

<!-- clova issue로 분기 -->
<script type="text/javascript" src="/js/swfobject/swfobject.js"></script>

<!-- java enum to js -->
<script type="text/javascript" src="https://music.bugs.co.kr/js/enumtojs"></script>

<script type="text/javascript" src="/js/utils/personMedia.js?version=20220420"></script>
<script type="text/javascript" src="/js/me/playlist.js?version=20151102"></script>
<script type="text/javascript" src="/js/log/makePCookie.js"></script>

<script type="text/javascript" src="/js/player/min/mvHtml5Player.min.js?version=20251206:1255"></script>

<!-- <script type="text/javascript" src="/js/utils/fileUploader.js"></script> -->

<script type="text/javascript" src="/js/lib/kakao.min.js"></script> <!-- <script type="text/javascript" src="/js/lib/kakao.story.min.js"></script> -->

<!--[if gt IE 7]>
<script type="text/javascript" src="/js/jquery/jquery.ba-hashchange.min.js"></script>
<![endif]-->

<!--[if lt IE 9]>
<script type="text/javascript" src="/js/html5/html5shiv.min.js"></script>
<script type="text/javascript" src="/js/json2.js"></script>
<![endif]-->


<!-- bugs file packing [ bugs_commonStyle_css ] cached data / start -->
<link rel='stylesheet' type='text/css' href='//music.bugs.co.kr/filepacking/bugs_commonStyle_css?env=svc&_t_s_=20251206-1255' />
<!-- bugs file packing [ bugs_commonStyle_css ] cached data / end -->


<script async type="text/javascript" src="//cdn.nhnace.com/libs/aceat.js?pub_code=1955139738"></script>
<script type="text/javascript" src="https://challenges.cloudflare.com/turnstile/v0/api.js?render=explicit"></script>
<script type="text/javascript" src="//music.bugs.co.kr/js/utils/cfTurnstile.js"></script>
<meta name="twitter:card" content="summary_large_image">
<meta name="twitter:url" content="https://music.bugs.co.kr/chart/track/realtime/total">
<meta name="twitter:description" content="벅스!에서 다양한 음악컨텐츠를 볼 수 있습니다.">
<meta name="twitter:image:src" content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png">
<meta name="twitter:app:url:iphone" content="bugs3://app/whatshot/chart">
<meta name="twitter:app:url:ipad" content="bugs3://app/whatshot/chart">
<meta name="twitter:app:url:googleplay" content="bugs3://app/whatshot/chart">








<meta name="description" content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지" />

<!-- open graph -->
<meta property="fb:app_id" content="122936701116206" />
<meta property="og:title" content="나를 위한 플리, 벅스"/>
<meta property="og:url" content="https://music.bugs.co.kr/chart"/>
<meta property="og:image" content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" />
<meta property="og:site_name" content="벅스!"/>
<meta property="og:description" content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지"/>
<meta property="og:type" content="website" />
<meta property="og:locale" content="ko_KR" />

<!-- twitter card -->
<meta name="twitter:card" content="summary_large_image">
<meta name="twitter:url" content="https://music.bugs.co.kr/chart">
<meta name="twitter:site" content="@Bugs_play">
<meta name="twitter:title" content="나를 위한 플리, 벅스">
<meta name="twitter:description" content="나를 위한 플리, 벅스! 마음을 담은 노래추천 플레이리스트, 그리고 일상을 감성으로 가득 채워줄 essential player까지">
<meta name="twitter:image" content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png">
<meta name="twitter:image:src" content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png">
<meta name="twitter:app:name:iphone" content="벅스">
<meta name="twitter:app:name:ipad" content="벅스">
<meta name="twitter:app:name:googleplay" content="벅스">
<meta name="twitter:app:url:iphone" content="https://music.bugs.co.kr/chart">
<meta name="twitter:app:url:ipad" content="https://music.bugs.co.kr/chart">
<meta name="twitter:app:url:googleplay" content="https://music.bugs.co.kr/chart">
<meta name="twitter:app:id:iphone" content="348555322">
<meta name="twitter:app:id:ipad" content="420598915">
<meta name="twitter:app:id:googleplay" content="com.neowiz.android.bugs">
<link rel="image_src" href="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" />
<meta content="https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png" itemprop="image">
<!-- bugs.sns 용 공유 파라미터 -->
<script>
var bugsSnsParam = {
url : "https://music.bugs.co.kr/chart",
text : "나를 위한 플리, 벅스",
img : "https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png",
hashTag : "#벅스",
corner : "벅스"
}
</script>

<script>
var bugsSnsParam2 = {
url : "https://music.bugs.co.kr/chart",
text : "#2018_우리가_사랑한_음악",
img : "https://file.bugsm.co.kr/bdesign/sns/1200x630_bugs.png",
hashTag : "#벅스",
corner : "벅스"
}
</script>



<meta property="og:locale" content="ko_KR" />






<title>벅스차트 &gt; 곡 차트 &gt; 실시간 &gt; 전체 장르 - 벅스</title>
<meta http-equiv="Cache-Control" content="no-cache">
<meta http-equiv="Pragma" content="no-cache">
<meta http-equiv="Expires" content="0">
<!-- 네이버 검색용 메타 -->
<meta name="naver-site-verification" content="0582453e44d4365f5e597d1580911be7a3173ef7"/>
<!-- bugs file packing [ bugs_wbugsAll_css ] cached data / start -->
<link rel='stylesheet' type='text/css' href='//music.bugs.co.kr/filepacking/bugs_wbugsAll_css?env=svc&_t_s_=20251206-1255' />
<!-- bugs file packing [ bugs_wbugsAll_css ] cached data / end -->


<link rel="shortcut icon" href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" type="image/x-icon" />
<link rel="icon" href="https://file.bugsm.co.kr/wbugs/common/faviconBugs.ico" type="image/x-icon" />


<script src='/js/log/ace_counter.js'></script>

<script>
$(document).ready(function(){
$("[dotdotdot=Y]").dotdotdot({
watch : "window"
});
});
</script>

<meta name="last-process-time" content="">


<span itemscope="" itemtype="http://schema.org/Organization">
<link itemprop="url" href="http://music.bugs.co.kr">
<a itemprop="sameAs" href="https://www.facebook.com/bugsplay"></a>
<a itemprop="sameAs" href="http://blog.bugs.co.kr"></a>
<a itemprop="sameAs" href="https://twitter.com/bugs_play"></a>
<a itemprop="sameAs" href="https://itunes.apple.com/kr/app/bugs/id348555322?mt=8"></a>
<a itemprop="sameAs" href="https://play.google.com/store/apps/details?id=com.neowiz.android.bugs"></a>
</span>
<script type="text/javascript">
(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
})(window,document,'script','//www.google-analytics.com/analytics.js','ga');



try {
ga('create', 'UA-97174709-1', 'auto', 'billingTracker');
} catch (e) {
console.log('GoogleAnalytics Create Error');
}

var sendGoogleAnalyticsEventForBilling = function (category, action, label) {
try {
ga('billingTracker.send', 'event', category, action, label);
} catch (e) {
console.log('GoogleAnalytics Send Event Error');
}
}

</script>
</head>

<body>



<div id="skipNav">
<a href="#container" onclick="$('#container').attr('tabIndex','-1');$('#container').focus();$('body,html').scrollTop(0);return false;"><span>본문 바로가기</span></a>
<a href="#gnb" onclick="bugs.navigator.setLeftMenuShow(true,true);$('#gnb').attr('tabIndex','-1');$('#gnb').focus();return false;"><span>메뉴 바로가기</span></a>
<a href="#loginHeader" onclick="$('#loginHeader a:first-of-type').attr('tabIndex','-1');$('#loginHeader a:first-of-type').focus();return false;"><span>로그인 바로가기</span></a>
<a href="#footer" onclick="$('#footer').attr('tabIndex','-1');$('#footer').focus();return false;"><span>하단 정보 바로가기</span></a>
</div>

<div id="wrap">

<script>
$(document).ready(function(){
if('' == ""){
bugs.searchBoxAd.init();
bugs.searchBoxAd.checkInput();
bugs.searchBoxAd.inputBlur();
bugs.searchBoxAd.deleteText();
}
popWebPlayerNotification();
bugs.suggest.close();
var headerCommonBanner = '[{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/85\",\"view_target\":\"ALL\",\"title\":\"겨울 감성 발라드\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":129559,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/559/129/0/129559.jpg\",\"view_start_date\":{\"date\":1,\"hours\":12,\"seconds\":0,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":0,\"time\":1764558000000,\"day\":1},\"expire_day\":0,\"regdate\":{\"date\":1,\"hours\":11,\"seconds\":54,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":30,\"time\":1764556254000,\"day\":1},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":1,\"hours\":11,\"seconds\":57,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":33,\"time\":1764556437000,\"day\":1},\"view_end_date\":{\"date\":6,\"hours\":17,\"seconds\":0,\"month\":2,\"timezoneOffset\":-540,\"year\":126,\"minutes\":0,\"time\":1772784000000,\"day\":5},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/32685\",\"view_target\":\"ALL\",\"title\":\"겨울 노래\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":129557,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/557/129/0/129557.jpg\",\"view_start_date\":{\"date\":1,\"hours\":12,\"seconds\":0,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":0,\"time\":1764558000000,\"day\":1},\"expire_day\":0,\"regdate\":{\"date\":1,\"hours\":11,\"seconds\":38,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":29,\"time\":1764556178000,\"day\":1},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":1,\"hours\":11,\"seconds\":38,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":29,\"time\":1764556178000,\"day\":1},\"view_end_date\":{\"date\":6,\"hours\":17,\"seconds\":0,\"month\":2,\"timezoneOffset\":-540,\"year\":126,\"minutes\":0,\"time\":1772784000000,\"day\":5},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"main\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/36142\",\"view_target\":\"ALL\",\"title\":\"겨울 신나는 가요\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":129555,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/555/129/0/129555.jpg\",\"view_start_date\":{\"date\":1,\"hours\":12,\"seconds\":0,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":0,\"time\":1764558000000,\"day\":1},\"expire_day\":0,\"regdate\":{\"date\":1,\"hours\":11,\"seconds\":27,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":28,\"time\":1764556107000,\"day\":1},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":1,\"hours\":11,\"seconds\":27,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":28,\"time\":1764556107000,\"day\":1},\"view_end_date\":{\"date\":6,\"hours\":17,\"seconds\":0,\"month\":2,\"timezoneOffset\":-540,\"year\":126,\"minutes\":0,\"time\":1772784000000,\"day\":5},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"}]||[{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"sub\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/85\",\"view_target\":\"ALL\",\"title\":\"겨울 감성 발라드\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":129560,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/560/129/0/129560.jpg\",\"view_start_date\":{\"date\":1,\"hours\":12,\"seconds\":0,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":0,\"time\":1764558000000,\"day\":1},\"expire_day\":0,\"regdate\":{\"date\":1,\"hours\":11,\"seconds\":19,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":31,\"time\":1764556279000,\"day\":1},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":1,\"hours\":11,\"seconds\":19,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":31,\"time\":1764556279000,\"day\":1},\"view_end_date\":{\"date\":6,\"hours\":17,\"seconds\":0,\"month\":2,\"timezoneOffset\":-540,\"year\":126,\"minutes\":0,\"time\":1772784000000,\"day\":5},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"sub\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/32685\",\"view_target\":\"ALL\",\"title\":\"겨울 노래\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":129558,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/558/129/0/129558.jpg\",\"view_start_date\":{\"date\":1,\"hours\":12,\"seconds\":0,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":0,\"time\":1764558000000,\"day\":1},\"expire_day\":0,\"regdate\":{\"date\":1,\"hours\":11,\"seconds\":12,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":30,\"time\":1764556212000,\"day\":1},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":1,\"hours\":11,\"seconds\":6,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":34,\"time\":1764556446000,\"day\":1},\"view_end_date\":{\"date\":6,\"hours\":17,\"seconds\":0,\"month\":2,\"timezoneOffset\":-540,\"year\":126,\"minutes\":0,\"time\":1772784000000,\"day\":5},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"},{\"image_bg_color\":\"\",\"clickCount\":0,\"artist\":null,\"sub_category\":\"sub\",\"crt_dt\":\"\",\"db_sts\":\"\",\"link\":\"https://music.bugs.co.kr/musicpd/albumview/36142\",\"view_target\":\"ALL\",\"title\":\"겨울 신나는 가요\",\"str_content_id\":\"0\",\"content_type\":\"NONE\",\"crt_id\":\"\",\"track\":null,\"view_env\":\"SVC\",\"content_id2\":\"\",\"pay_yn\":\"\",\"banner_id\":129556,\"content_id\":0,\"album\":null,\"upd_dt\":\"\",\"mv\":null,\"weight\":20,\"image_path2\":\"\",\"artist_id\":\"0\",\"mobile_target\":\"\",\"target\":\"_self\",\"upd_id\":\"\",\"wiselog_code\":\"\",\"file_ext\":\"\",\"css_class_nm\":\"\",\"image_path\":\"//image.bugsm.co.kr/banner/images/original/556/129/0/129556.jpg\",\"view_start_date\":{\"date\":1,\"hours\":12,\"seconds\":0,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":0,\"time\":1764558000000,\"day\":1},\"expire_day\":0,\"regdate\":{\"date\":1,\"hours\":11,\"seconds\":59,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":28,\"time\":1764556139000,\"day\":1},\"totalWeight\":0,\"app_nm\":\"\",\"album_id\":\"0\",\"lastupdate\":{\"date\":1,\"hours\":11,\"seconds\":59,\"month\":11,\"timezoneOffset\":-540,\"year\":125,\"minutes\":28,\"time\":1764556139000,\"day\":1},\"view_end_date\":{\"date\":6,\"hours\":17,\"seconds\":0,\"month\":2,\"timezoneOffset\":-540,\"year\":126,\"minutes\":0,\"time\":1772784000000,\"day\":5},\"category\":\"WBUGS_HEADER_COMMON_BANNER\",\"status\":\"OK\"}]';
if(headerCommonBanner != ""){
window._headerCommonBannerMainList = bugs.utils.parseJson(headerCommonBanner.split("||")[0]);
window._headerCommonBannerSubList = bugs.utils.parseJson(headerCommonBanner.split("||")[1]);
}
headerCommonBannerLoad(location.href);
if(bugs.cookie.get("hasCouponEmailID") == "1"){
$("#no_coupon_text").append('<a href="http://help.bugs.co.kr/sub?target=bugs/faq/list%3FfaqId%3D26048%26categoryNo%3D4600" class="linkFAQ" target="_blank">구매한 이용권이 보이지 않는다면?</a>');
}
});
function popWebPlayerNotification() {
var flag = Cookies.get("wpn");
if(!flag)
$(".slogan .tip").show();
else
$(".slogan .tip").hide();
};
function closeWebPlayerNotification() {
Cookies.set("wpn", "Y", {expires:365*50, path:"/", domain:document.domain});
$(".slogan .tip").hide();
}
function headerCommonBannerLoad(url){
// url = window.location.href; //테스트용
if(url.indexOf("?") > 0){
url = url.substring(0,url.indexOf("?"))
}

if(url == g_urlWww || url == g_urlWww+"/" || url == g_urlWww+"/index" || url == g_urlMusic){ //main
if(typeof window._headerCommonBannerSubList != "undefined" && window._headerCommonBannerMainList.length > 0){
var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerMainList);
$('#header div.header div.banner').empty();
$('#header div.header div.banner').append('<a href="'+ bugs.common_util.setLinkUrlWiseLog(selectedBanner.link, "M_header_03_03") +'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
}
}else{ //sub
if(typeof window._headerCommonBannerSubList != "undefined" && window._headerCommonBannerSubList.length > 0){
var selectedBanner = bugs.utils.getBannerRandomExtractByWeight(window._headerCommonBannerSubList);
$('#header div.header div.banner').empty();
$('#header div.header div.banner').append('<a href="'+selectedBanner.link+'" target="'+selectedBanner.target+'" onclick="bugs.logging.banner('+selectedBanner.banner_id+','+"'banner'"+')" title="'+selectedBanner.title+'-페이지 이동">'+
'<img src="'+selectedBanner.image_path+'" alt="'+selectedBanner.title+'"></a>');
}
}

};
</script>
<header id="header">




<aside class="layer layerSettingPlayer guide title" style="display:none;">
<div class="box-shadow"></div>

<header class="layer-title">
<h1>안내</h1>
</header>

<section class="layerContents">
<p class="message">
음악을 재생할 플레이어를 선택해 주세요. <br/>
벅스 웹상단 &gt; <strong>플레이어 선택</strong>에서 플레이어를 변경할 수 있습니다.
</p>
<fieldset>
<div class="radioChk"><input type="radio" id="radio_player_web2" name="radio_player_type2" value="WEB" checked="checked"> <label for="radio_player_web2">웹 플레이어</label></div>
<div class="radioChk"><input type="radio" id="radio_player_mac2" name="radio_player_type2" value="MAC"> <label for="radio_player_mac2">벅스 플레이어 (프로그램 설치 필요)</label>
<p>
v 1.3.0 미만인 경우, 최신 버전으로 업데이트 해주세요.<br/>
<a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">[설치 안내 바로가기]</a>
</p>
</div>
</fieldset>
<p class="agreeCheck">
<input type="checkbox" id="setPlayerSelectionConfirm" name="setPlayer"> <label for="setPlayerSelectionConfirm">항상 선택한 플레이어로 재생</label>
</p>

<p class="btns">
<button class="btnNormal" type="ok">확인</button>
</p>
</section>
<button class="btnClose" type="cancel">닫기</button>
</aside>
<!-- //플레이어 선택 설정 안내 -->

<aside class="layer layerSettingPlayer selectPlayer title" style="display:none;">
<div class="box-shadow"></div>

<header class="layer-title">
<h1>플레이어 선택</h1>
</header>

<section class="layerContents">
<p class="message">음악을 재생할 플레이어를 선택해 주세요.</p>
<fieldset>
<div class="radioChk">
<input type="radio" id="radio_player_web1" name="radio_player_type1" value="WEB" checked="checked"> <label for="radio_player_web1">웹 플레이어</label>
</div>
<div class="radioChk">
<input type="radio" id="radio_player_mac1" name="radio_player_type1" value="MAC"> <label for="radio_player_mac1">벅스 플레이어 (프로그램 설치 필요)</label>
<p>
v 1.3.0 미만인 경우, 최신 버전으로 업데이트 해주세요.<br/>
<a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" target="_blank">[설치 안내 바로가기]</a>
</p>
</div>
</fieldset>

<p class="btns">
<button class="btnNormal" type="ok">확인</button>
</p>
</section>
<button class="btnClose" type="cancel">닫기</button>
</aside>
<!-- //플레이어 선택 안내 -->


<!--
<aside class="layer layerPlayingPlayer" style="display:none;">
<div class="box-shadow"></div>

<section class="layerContents">
<strong class="message">벅스 플레이어로 재생됩니다.</strong>
<ul>
<li>벅스 웹상단 &gt; 플레이어 선택에서 플레이어를 변경할 수 있습니다.</li>
<li>혹시 벅스 플레이어가 실행되지 않는다면? <a href="https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer" onclick="$('.layerPlayingPlayer').hide();" target="_blank">[설치 안내 바로가기]</a></li>
</ul>
</section>
</aside>
-->
<script type="text/javascript">
// var ua = navigator.userAgent;
// window._isMacBrowser = navigator.userAgent.search("Mac") > -1;
// window._isMacPlayerLinked = /Mac OS X 11_/.test(ua)
// || /Mac OS X 12_/.test(ua)
// || (/Mac OS X 10_/.test(ua) && !/Mac OS X 10_10/.test(ua) && !/Mac OS X 10_9/.test(ua) && !/Mac OS X 10_8/.test(ua) && !/Mac OS X 10_7/.test(ua) && !/Mac OS X 10_6/.test(ua) && !/Mac OS X 10_5/.test(ua)
// && !/Mac OS X 10_4/.test(ua) && !/Mac OS X 10_3/.test(ua) && !/Mac OS X 10_2/.test(ua));

var goServiceGuidePlayerPage = function(){
if(navigator.platform.indexOf('Win') > -1){
document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer";
}else{
document.location.href = "https://music.bugs.co.kr/serviceGuide/pc/bugsPlayer?sub=macPlayer";
}
}

$(document).ready(function() {
showMacPlayerSelection();

});

var showMacPlayerSelection = function() {
if(bugs.music.isMacPlayerSupport()) {
$(".slogan .selectPlayer").show();
$(".slogan .goGuideBugsPlayer").hide();

var dp = bugs.cookie.get('defaultPlayer') || "";
updateHeaderPlayerMenu(dp);
} else {
$(".slogan .selectPlayer").hide();
$(".slogan .goGuideBugsPlayer").show();
}
}

var updateHeaderPlayerMenu = function(type) {
$("#headerWebPlayer").hide();
$("#headerMacPlayer").hide();

if(type == "MAC") {
$("#headerMacPlayer").show();
} else { // if(type == "" || type == "WEB") {
$("#headerWebPlayer").show();
$("#headerWebPlayer").removeAttr("onclick");
$("#headerWebPlayer").unbind("click").bind("click", function() {
bugs.music.popWebPlayer();
bugs.wiselog.area('M_header_02_20');
return false;
});
}
}
</script>

<div class="top">
<div class="slogan">
<a href="https://music.bugs.co.kr/musicpd?wl_ref=M_header_02_21" class="btnPlaylistForMe">나를 위한 플리</a>
<a href="https://music.bugs.co.kr/promotion/essentialPlayerIntroduce?wl_ref=M_header_02_22" class="btnEssential" target="_blank">essential;</a>

<a id="headerWebPlayer" href="javascript:;" onclick="javascript:bugs.music.popWebPlayer();bugs.wiselog.area('M_header_02_13');return false;" class="openPlayer" aria-label="새창">웹 플레이어</a>
<a id="headerMacPlayer" href="bugs3://app/wakeup" onclick="bugs.wiselog.area('M_header_02_18');" class="openPlayer" style="display:none;">벅스 플레이어</a>
<span class="goGuideBugsPlayer" style="display:none;">
<a href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_14');}catch(e){} goServiceGuidePlayerPage();">벅스 플레이어</a>
</span>
<a href="javascript:;" onclick="bugs.ui.showPlayerSettingLayer();bugs.wiselog.area('M_header_02_19');" class="selectPlayer" aria-label="새창" style="display:none;">플레이어 선택</a>
</div>

<div class="rightGroup">
<div class="more">
<a href="http://help.bugs.co.kr" onclick="try{bugs.wiselog.area('M_header_02_06');}catch(e){}">고객센터</a>
<a href="javascript:;" onclick="try{bugs.wiselog.area('M_header_02_08');}catch(e){}bugs.ui.cp.headerGameMenuToggle();" class="game">게임</a>

<aside class="layer gameMenu">
<div class="box-shadow"></div>
<ul class="list-layer-select">
<li><a href="https://game.bugs.co.kr?wl_ref=sub_gnb&wl_ref=M_header_02_11" onclick="try{bugs.wiselog.area('M_header_02_11');}catch(e){}" target='_blank' data-restricted="hangame">피망</a></li>
</ul>
</aside>
</div>

<div class="family">
<a href="http://www.ticketlink.co.kr" onclick="try{bugs.wiselog.area('M_header_02_04');}catch(e){}" class="ticketlink" target="_blank">티켓링크</a>
<a href="https://www.hangame.com" onclick="try{bugs.wiselog.area('M_header_02_05');}catch(e){}" class="hangame" target="_blank">HANGAME</a>
</div>

</div>
</div>

<div class="header">
<a href="https://music.bugs.co.kr?wl_ref=M_header_03_01" class="logo seasonal hyrend">Bugs!<span class="blind">-홈으로 이동</span></a>
<div class="innerContainer">
<input type="hidden" id="_hsi"/>
<fieldset class="searchForm" id="hederSearchForm">
<div class="input">
<input type="text" id="headerSearchInput" title="검색어 입력" autocomplete="off" /><span class="adKeywordDelete" id="keywordClearButton"><span class="blind">검색어 삭제</span></span><button class="btnSearch" id="hederSearchFormButton" onclick="bugs.search.searchFromButton();">검색<span class="blind">-페이지 이동</span></button>
</div>
<div id="suggest" style="display:none;">
<div class="box-shadow"></div>
</div>
</fieldset>
<div class="banner"></div>
</div>
<div class="rightSection">

<div class="member">

<div id="loginHeader" class="login">
<!-- <a href="javascript:bugs.ui.showLoginLayerForHeader();" onclick="javascript:bugs.wiselog.area('M_header_03_05');">로그인</a>
<a href="https://secure.bugs.co.kr/member/join/memberMain?wl_ref=M_header_03_06" class="signup"><span class="bar"></span> 회원가입<span class="blind">-페이지 이동</span></a> -->
<a href="javascript:void(0);" onclick="bugs.wiselog.area('M_header_03_05');bugs.ui.showLoginLayerForHeader({caller:this});">로그인 / 회원가입</a>
</div>

<div class="notification" id="memberNotificationArea">
<button id="btnNotificationMain" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;">알림</button>
<button id="aNotificationMain" class="count" onclick="bugs.notice.pop(this, g_isLogged);bugs.wiselog.area('M_header_03_04');" style="display:none;"><span class="blind">새로운</span><span>알림</span>0<span class="blind">개</span></button>
</div>
</div>
</div>

</div>
</header><div id="gnb">
<span id="gnbHandleBtn" class="btnMenuFolding" style="display:none">MENU</span>

<div id="gnbBody">
<div class="links">
<div class="inner">
<a href="https://music.bugs.co.kr/member/vipinfo?wl_ref=M_header_02_12" class="btnNormal lounge">벅스 VIP 멤버십 안내</a>
<a href="https://music.bugs.co.kr/pay/recommend?wl_ref=M_left_01_01" class="link ticket" data-restricted="hangame" data-restricted-button="pay">이용권 구매</a>
<a href="https://music.bugs.co.kr/pay/offlineCoupon?wl_ref=M_left_01_01" class="link coupon" data-restricted="hangame">상품권 등록</a>
</div>
</div>

<nav>
<ul>
<li class="chart"><a href="https://music.bugs.co.kr/chart?wl_ref=M_left_02_01" class="hyrend" lmid="lm_chart">벅스차트</a></li>
<li class="news"><a href="https://music.bugs.co.kr/newest?wl_ref=M_left_02_03" class="hyrend" lmid="lm_news">최신 음악</a></li>
<li class="music4u"><a href="https://music.bugs.co.kr/music4u?wl_ref=M_left_02_02" class="hyrend" lmid="lm_m4u" loginRequired="PAGE">뮤직4U</a></li>
<li class="genre"><a href="https://music.bugs.co.kr/genre/home?wl_ref=M_left_02_06" class="hyrend" lmid="lm_genre">장르</a></li>
<li class="special"><a href="https://music.bugs.co.kr/musicpost?wl_ref=M_left_02_08" class="hyrend" lmid="lm_special">뮤직포스트</a></li>
<li class="theme open" folder="2">
<strong>테마</strong><span class="bu"></span>
<ul>
<li><a href="https://music.bugs.co.kr/musicpd?wl_ref=M_left_02_04" class="hyrend" lmid="lm_esalbum">뮤직PD 앨범</a></li>
<li><a href="https://music.bugs.co.kr/recomreview?wl_ref=M_left_02_05" class="hyrend" lmid="lm_recomreview">추천앨범 리뷰</a></li>
<li><a href="https://music.bugs.co.kr/years?wl_ref=M_left_02_07" class="hyrend" lmid="lm_years">연도별</a></li>
</ul>
</li>
<li class="favorite open" folder="3">
<strong>투표 <span class="iconNew">NEW</span></strong><span class="bu"></span>
<ul>
<li><a href="https://favorite.bugs.co.kr?wl_ref=M_left_02_14" lmid="lm_favorite">Favorite</a></li>
<li><a href="https://favorite.bugs.co.kr/heartchargingstation?wl_ref=M_left_02_14" lmid="lm_heartchargingstation" data-restricted="hangame">하트 충전소</a></li>
</ul>
</li>
<li class="connect"><a href="https://music.bugs.co.kr/connect?wl_ref=M_left_02_13" class="hyrend" lmid="lm_connect">커넥트 </a></li>
<li class="radio"><a href="https://music.bugs.co.kr/radio/radioChannel?wl_ref=M_left_02_10" class="hyrend" lmid="lm_radio">라디오</a></li>
<li class="bugsonTV open" folder="5">
<strong>벅스TV</strong><span class="bu"></span>
<ul>
<li class="specialLive"><a href="https://music.bugs.co.kr/musicpost/list/bugstv?wl_ref=M_left_04_04">스페셜 라이브</a></li>
</ul>
</li>

<li class="mymusic open" folder="3">
<strong>내 음악</strong><span class="bu"></span>
<ul>
<li><a href="https://music.bugs.co.kr/user/library/listen?wl_ref=M_left_03_05" lmid="lm_recentTrack" loginRequired="PAGE">최근 들은 곡</a> <button onclick="bugs.music.myAlbumList.listenListenedList('',true);" aria-label="새창">최근 들은 곡 재생</button></li>
<li><a href="https://music.bugs.co.kr/user/library/listen?sort=LISTEN_COUNT&wl_ref=M_left_03_06" lmid="lm_manytimesTrack" loginRequired="PAGE">가장 많이 들은 곡</a> <button onclick="bugs.music.myAlbumList.listenListenedList('LISTEN_COUNT',true);" aria-label="새창">가장 많이 들은 곡 재생</button></li>
<li><a href="https://music.bugs.co.kr/user/library/purchased/track?wl_ref=M_left_03_01" lmid="lm_buymusic" loginRequired="PAGE">구매한 음악</a></li>
<li><a href="https://music.bugs.co.kr/user/library/like/track?wl_ref=M_left_03_02" lmid="lm_likemusic" loginRequired="PAGE">좋아한 음악</a></li>
<li><a href="https://music.bugs.co.kr/user/library/myalbum/list?wl_ref=M_left_03_03" lmid="lm_myAlbumManage" loginRequired="PAGE">내앨범</a></li>
</ul>
</li>
</ul>
</nav>
</div>
</div>
<script>
try{
bugs.navigator.setLeftMenuFolder();
}
catch(e){}
</script>
<div id="hyrendContentBody" >




<article id="container" class="mnWhatshot mnChart pgChartTrack">

<header class="sectionPadding pgTitle">
<div class="innerContainer">
<h1>벅스차트</h1>
<script type="text/javascript">
var toggleNationLayer = function() {
$("aside.selectNation").toggle(250, function(){});
}

$(document).ready(function () {

function changeTitle(){
try{
if('KR' != 'KR'){
var newTitle = '벅스차트 > 곡 차트 > 대한민국 - 벅스';
var curTitle = document.title;
if(newTitle != curTitle){
document.title = newTitle;
} else {
setTimeout(changeTitle, 500);
}
}
} catch(e){}
};

changeTitle();

$(document).click(function(ev){
if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
if ($(ev.target).attr('class') != "selectedNationName"
&& ($(ev.target).attr('class').indexOf("flag") != 0 )
&& ($(ev.target).attr('class').indexOf("btnNation") == -1 ) ) {
$("aside.selectNation").hide(250);
}
});
});
</script>

<aside class="layer selectNation">
<div class="box-shadow"></div>
<h1>국가선택</h1>
<ul>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?nation=KR"
onclick = "bugs.wiselog.area('chart_nation_KR');"
class="hyrend selected KR" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/KR.png" alt="" /></span><em class="selectedNationName">대한민국</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=nl"
onclick = "bugs.wiselog.area('chart_nation_nl');"
class="hyrend nl" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/NL.png" alt="" /></span><em class="selectedNationName">네덜란드</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=dk"
onclick = "bugs.wiselog.area('chart_nation_dk');"
class="hyrend dk" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/DK.png" alt="" /></span><em class="selectedNationName">덴마크</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=de"
onclick = "bugs.wiselog.area('chart_nation_de');"
class="hyrend de" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/DE.png" alt="" /></span><em class="selectedNationName">독일</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=us"
onclick = "bugs.wiselog.area('chart_nation_us');"
class="hyrend us" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/US.png" alt="" /></span><em class="selectedNationName">미국</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=be"
onclick = "bugs.wiselog.area('chart_nation_be');"
class="hyrend be" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/BE.png" alt="" /></span><em class="selectedNationName">벨기에</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=br"
onclick = "bugs.wiselog.area('chart_nation_br');"
class="hyrend br" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/BR.png" alt="" /></span><em class="selectedNationName">브라질</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=se"
onclick = "bugs.wiselog.area('chart_nation_se');"
class="hyrend se" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/SE.png" alt="" /></span><em class="selectedNationName">스웨덴</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=es"
onclick = "bugs.wiselog.area('chart_nation_es');"
class="hyrend es" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/ES.png" alt="" /></span><em class="selectedNationName">스페인</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=ar"
onclick = "bugs.wiselog.area('chart_nation_ar');"
class="hyrend ar" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/AR.png" alt="" /></span><em class="selectedNationName">아르헨티나</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=gb"
onclick = "bugs.wiselog.area('chart_nation_gb');"
class="hyrend gb" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/GB.png" alt="" /></span><em class="selectedNationName">영국</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=it"
onclick = "bugs.wiselog.area('chart_nation_it');"
class="hyrend it" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/IT.png" alt="" /></span><em class="selectedNationName">이탈리아</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=ca"
onclick = "bugs.wiselog.area('chart_nation_ca');"
class="hyrend ca" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/CA.png" alt="" /></span><em class="selectedNationName">캐나다</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=fi"
onclick = "bugs.wiselog.area('chart_nation_fi');"
class="hyrend fi" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/FI.png" alt="" /></span><em class="selectedNationName">핀란드</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=fr"
onclick = "bugs.wiselog.area('chart_nation_fr');"
class="hyrend fr" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/FR.png" alt="" /></span><em class="selectedNationName">프랑스</em></a></li>
<li><a href="https://music.bugs.co.kr/chart/track/week/total?nation=au"
onclick = "bugs.wiselog.area('chart_nation_au');"
class="hyrend au" ><span class="flag"><img src="https://file.bugsm.co.kr/wbugs/api/flag/square/AU.png" alt="" /></span><em class="selectedNationName">호주</em></a></li>
</ul>
</aside>
<a href="javascript:;" onclick="bugs.wiselog.area('S_gfilter_01');toggleGenreLayer();" class="btnGenre"><em class="selectedGenreName">전체 장르</em></a>
<script type="text/javascript">
<!--
var toggleGenreLayer = function() {
$("aside.selectGenre").toggle(250, function(){});
$('aside.coachBside').hide();
}

var setSelectedType = function(selectedType) {
if (selectedType == "") selectedType = "total";
$('ul.listGenre > li > a').each(function(index) {$(this).removeClass('selected')});
$('ul.listGenre > li[type='+selectedType+'] > a').addClass('selected');
}

jQuery(document).ready(function () {
setSelectedType("total");

$(document).click(function(ev){
try{
if( typeof($(ev.target).attr('class')) === 'undefined' ) return;
if ($(ev.target).attr('class') != "selectedGenreName"
&& ($(ev.target).attr('class').indexOf("btnGenre") == -1) ) {
$("aside.selectGenre").hide(250);
}
}catch(e){}
});
});
//-->
</script>

<!-- 장르선택 레이어 -->
<aside class="layer selectGenre">
<div class="box-shadow"></div>

<h1>장르선택</h1>
<ul class="category">
<li>
<em class="all">전체</em>
<ul class="listGenre">
<li type="total"><a href="https://music.bugs.co.kr/chart/track/realtime/total" class="selected hyrend">전체 장르</a></li>
<li type="kpop"><a href="https://music.bugs.co.kr/chart/track/realtime/kpop" class="hyrend">국내 전체 장르</a></li>
<li type="pop"><a href="https://music.bugs.co.kr/chart/track/realtime/pop" class="hyrend">해외 전체 장르</a></li>
</ul>
</li>
<li>
<em class="domestic">국내</em>
<ul class="listGenre">
<li type="nb"><a href="https://music.bugs.co.kr/chart/track/day/nb" data-category="domestic" class="hyrend">발라드</a></li>
<li type="ndp"><a href="https://music.bugs.co.kr/chart/track/day/ndp" data-category="domestic" class="hyrend">댄스/팝</a></li>
<li type="nfa"><a href="https://music.bugs.co.kr/chart/track/day/nfa" data-category="domestic" class="hyrend">포크/어쿠스틱</a></li>
<li type="nid"><a href="https://music.bugs.co.kr/chart/track/day/nid" data-category="domestic" class="hyrend">아이돌</a></li>
<li type="nrh"><a href="https://music.bugs.co.kr/chart/track/day/nrh" data-category="domestic" class="hyrend">랩/힙합</a></li>
<li type="nrs"><a href="https://music.bugs.co.kr/chart/track/day/nrs" data-category="domestic" class="hyrend">알앤비/소울</a></li>
<li type="nkelec"><a href="https://music.bugs.co.kr/chart/track/day/nkelec" data-category="domestic" class="hyrend">일렉트로닉</a></li>
<li type="nkrock"><a href="https://music.bugs.co.kr/chart/track/day/nkrock" data-category="domestic" class="hyrend">락/메탈</a></li>
<li type="nkjazz"><a href="https://music.bugs.co.kr/chart/track/day/nkjazz" data-category="domestic" class="hyrend">재즈</a></li>
<li type="nindie"><a href="https://music.bugs.co.kr/chart/track/day/nindie" data-category="domestic" class="hyrend">인디</a></li>
<li type="ntrot"><a href="https://music.bugs.co.kr/chart/track/day/ntrot" data-category="domestic" class="hyrend">성인가요</a></li>
</ul>
</li>
<li>
<em class="overseas">해외</em>
<ul class="listGenre">
<li type="nfpop"><a href="https://music.bugs.co.kr/chart/track/day/nfpop" data-category="overseas" class="hyrend">팝</a></li>
<li type="nfhiphop"><a href="https://music.bugs.co.kr/chart/track/day/nfhiphop" data-category="overseas" class="hyrend">랩/힙합</a></li>
<li type="nfrnb"><a href="https://music.bugs.co.kr/chart/track/day/nfrnb" data-category="overseas" class="hyrend">알앤비/소울</a></li>
<li type="nfelec"><a href="https://music.bugs.co.kr/chart/track/day/nfelec" data-category="overseas" class="hyrend">일렉트로닉</a></li>
<li type="nfrock"><a href="https://music.bugs.co.kr/chart/track/day/nfrock" data-category="overseas" class="hyrend">락</a></li>
<li type="nfmetal"><a href="https://music.bugs.co.kr/chart/track/day/nfmetal" data-category="overseas" class="hyrend">메탈</a></li>
<li type="nfjazz"><a href="https://music.bugs.co.kr/chart/track/day/nfjazz" data-category="overseas" class="hyrend">재즈</a></li>
</ul>
</li>
<li>
<em class="etc">기타</em>
<ul class="listGenre">
<li type="nost"><a href="https://music.bugs.co.kr/chart/track/day/nost" data-category="etc" class="hyrend">OST</a></li>
<li type="nclassic"><a href="https://music.bugs.co.kr/chart/track/day/nclassic" data-category="etc" class="hyrend">클래식</a></li>
<li type="nnewage"><a href="https://music.bugs.co.kr/chart/track/day/nnewage" data-category="etc" class="hyrend">뉴에이지</a></li>
<li type="njpop"><a href="https://music.bugs.co.kr/chart/track/day/njpop" data-category="etc" class="hyrend">J-POP</a></li>
<li type="nwpop"><a href="https://music.bugs.co.kr/chart/track/day/nwpop" data-category="etc" class="hyrend">월드뮤직</a></li>
<li type="nkclassic"><a href="https://music.bugs.co.kr/chart/track/day/nkclassic" data-category="etc" class="hyrend">국악</a></li>
<li type="nccm"><a href="https://music.bugs.co.kr/chart/track/day/nccm" data-category="etc" class="hyrend">CCM/종교</a></li>
<li type="nchildren"><a href="https://music.bugs.co.kr/chart/track/day/nchildren" data-category="etc" class="hyrend">어린이</a></li>
<li type="nprenatal"><a href="https://music.bugs.co.kr/chart/track/day/nprenatal" data-category="etc" class="hyrend">태교</a></li>
<li type="ncarol"><a href="https://music.bugs.co.kr/chart/track/day/ncarol" data-category="etc" class="hyrend">캐롤</a></li>
</ul>
</li>
</ul>
</aside>
</div>
</header>

<script>
$(document).ready(function(){
if(bugs.cookie.get('bside_coach_mark') != "N"){
$('aside.coachConnect').show();
}
});

function bsideCoachMarkClick(){
var oDate = new Date();
oDate.setDate(oDate.getDate() + 3650); //10 years...
$('aside.coachConnect').hide();
bugs.cookie.set('bside_coach_mark', 'N', oDate, "/");
}


</script>

<nav class="sectionPadding lnb">
<div class="innerContainer">
<ul>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total" class="track hyrend">곡</a></li>
<li><a href="https://music.bugs.co.kr/chart/album/day/total" class="album hyrend">앨범</a></li>
<li><a href="https://music.bugs.co.kr/chart/pdalbum/day/total" class="mPDAlbum hyrend">뮤직PD 앨범</a></li>
<li><a href="https://music.bugs.co.kr/chart/mv/day/total" class="mv hyrend">영상</a></li>
<li>
<a href="https://music.bugs.co.kr/chart/connect/track/day/total" class="connectTrack hyrend">커넥트 곡</a>

<aside class="coachConnect" style="display:none;">
<p>
커넥트<br>
아티스트가 직접 올린 곡과 영상입니다.
<a href="https://music.bugs.co.kr/connect" class="hyrend">더 알아보기</a>
</p>
<button class="btnClose" onclick="bsideCoachMarkClick()">닫기</button>
</aside>
</li>
<li><a href="https://music.bugs.co.kr/chart/connect/mv/day/total" class="connectVideo hyrend">커넥트 영상</a></li>
</ul>
</div>
</nav>
<section class="sectionPadding">
<div class="innerContainer">

<fieldset class="filterChart" >
<legend>검색 필터</legend>

<div class="leftContents">
<p class="segmented">
<a href="https://music.bugs.co.kr/chart/track/realtime/total" class="first selected hyrend">실시간</a>
<a href="https://music.bugs.co.kr/chart/track/day/total" class=" hyrend">일간</a>
<a href="https://music.bugs.co.kr/chart/track/week/total" class="last hyrend">주간</a>
</p>
</div>
<time datetime="2025.12.06 11:00">

2025.12.06
<em>12:00</em>
<a href="javascript:void(0);" onClick="$('aside.realtime').css('left',$(this).offset().left-365);$('aside.realtime').css('top',$(this).offset().top-85);if($('aside.realtime').css('visibility')=='hidden')$('aside.realtime').css('visibility',''); else $('aside.realtime').css('visibility','hidden');" class="btnSelect" id="realtimeSelect">실시간 시간대 선택</a>
</time>

</fieldset>

<script type="text/javascript">
<!--
var __trackListCHARTrealtime = null;
$(function() {
__trackListCHARTrealtime = new bugs.music.trackList('realtime', 'CHART',false,0);
__trackListCHARTrealtime.initCheckBox();
});
-->
</script>
<div id="CHARTrealtime" >
<div class="listControls floatSubMenu" floataddclass="over" lmProp="width" >
<div class="innerContainer">
<label class="checkbox">
<input type="checkbox" id="checkCHARTrealtime" onclick="bugs.wiselog.area('list_tr_01_chart');" name="checkAll" title="곡 목록 전체">
</label>
<span class="btns">
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_02_chart');__trackListCHARTrealtime.listen(this,true);
"
class="btnNormal play" aria-label="새창"><span class="blind">선택된 곡 재생</span>듣기</a>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_03_chart');__trackListCHARTrealtime.listen(this,false);
"
class="btnNormal addPlaylist" aria-label="새창">재생목록에 추가</a>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_04_chart');__trackListCHARTrealtime.addToMyAlbum(this);
"
class="btnNormal addAlbum" aria-label="새창">내 앨범에 담기</a>
<a href="javascript:;" onclick=" bugs.wiselog.area('list_tr_05_chart');bugs.ui.showLoginLayer();" class="btnNormal download" data-restricted="hangame" aria-label="새창">다운로드</a>
</span>
<span class="btns play">
<span class="leftBar"></span>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_06_chart');__trackListCHARTrealtime.listenAll(this,'ALL', false);
"
class="btnNormal play" aria-label="새창">전체 듣기<small>(재생목록 추가)</small></a>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_18_chart');__trackListCHARTrealtime.listenAll(this,'ALL', true);
"
class="btnNormal play changePlaylist" aria-label="새창">전체 듣기<small>(재생목록 교체)</small></a>
</span>
</div>
</div>
<table class="list trackList byChart">
<caption>곡 목록</caption>
<thead >
<tr>
<th scope="col" class="check"></th>
<th scope="col" class="ranking"><span>순위</span></th>
<th scope="col" class="albumArt"></th>
<th scope="col" class="trackInfo"></th>
<th scope="col" class="title"><span>곡</span></th>
<th scope="col" class="artist"><span>아티스트</span></th>
<th scope="col" class="album"><span>앨범</span></th>
<th scope="col" class="action play"><span>듣기</span></th>
<th scope="col" class="action add01"><span>재생목록</span></th>
<th scope="col" class="action add02"><span>내앨범</span></th>
<th scope="col" class="action download"><span>다운</span></th>
<th scope="col" class="action mv"><span>영상</span></th>
<th scope="col" class="action etc"><span>기타</span></th>
</tr>
</thead>
<tbody>
<tr albumId="4130508" artistId="80177861" mvId="635262" trackId="6361285" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6361285" />
<input type="hidden" name="_isDown" value="6361285" />
<td class="check"><input type="checkbox" value="6361285" name="check" disc_id="1" title="Good Goodbye" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>1</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4130508?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41305/4130508.jpg?version=20251028010926" onerror="bugs.utils.imgError(this);" alt="Good Goodbye 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6361285?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6361285',true);
"
title="Good Goodbye" aria-label="새창">Good Goodbye</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80177861?wl_ref=list_tr_10_chart" title="화사 (HWASA)"
onclick="
">화사 (HWASA)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4130508?wl_ref=list_tr_11_chart" class="album" title="Good Goodbye"
onclick="
">Good Goodbye</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6361285',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6361285');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6361285');
"
track_title="Good Goodbye" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6361285','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6361285, 635262, 'Y', 'Y', 'Y', 'Y', 6361285, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6361285','0','4130508','bugs.music.listenRadioFromSeed(\'6361285\',\'track\');','N', 'Y', '_chart');
"
track_title="Good Goodbye"
artist_id="80177861"
artist_disp_nm="화사 (HWASA)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4133502" artistId="80408176" mvId="636056" trackId="6378118" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6378118" />
<input type="hidden" name="_isDown" value="6378118" />
<td class="check"><input type="checkbox" value="6378118" name="check" disc_id="1" title="ONE MORE TIME" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>2</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4133502?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41335/4133502.jpg?version=20251206014315" onerror="bugs.utils.imgError(this);" alt="ONE MORE TIME 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6378118?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6378118',true);
"
title="ONE MORE TIME" aria-label="새창">ONE MORE TIME</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80408176?wl_ref=list_tr_10_chart" title="ALLDAY PROJECT"
onclick="
">ALLDAY PROJECT</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4133502?wl_ref=list_tr_11_chart" class="album" title="ONE MORE TIME"
onclick="
">ONE MORE TIME</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6378118',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6378118');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6378118');
"
track_title="ONE MORE TIME" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6378118','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6378118, 636056, 'Y', 'Y', 'Y', 'Y', 6378118, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6378118','0','4133502','bugs.music.listenRadioFromSeed(\'6378118\',\'track\');','N', 'Y', '_chart');
"
track_title="ONE MORE TIME"
artist_id="80408176"
artist_disp_nm="ALLDAY PROJECT"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="38176338" artistId="14262785" mvId="0" trackId="125523552" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="125523552" />
<input type="hidden" name="_isDown" value="125523552" />
<td class="check"><input type="checkbox" value="125523552" name="check" disc_id="1" title="Golden" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>3</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/381763/38176338.jpg?version=20250927005933" onerror="bugs.utils.imgError(this);" alt="KPop Demon Hunters (Soundtrack from the Netflix Film) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/125523552?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('125523552',true);
"
title="Golden" aria-label="새창">Golden</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/80408375?wl_ref=list_tr_10_chart" class="artistTitle" title="HUNTR/X" >HUNTR/X</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'HUNTR/X||HUNTR/X||80408375||OK\\nEJAE||EJAE||20021140||OK\\nAUDREY NUNA||AUDREY NUNA||80332178||OK\\nREI AMI||REI AMI||20089314||OK\\nKPop Demon Hunters Cast||KPop Demon Hunters Cast||14262785||OK', ''); return false;">
HUNTR/X
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_11_chart" class="album" title="KPop Demon Hunters (Soundtrack from the Netflix Film)"
onclick="
">KPop Demon Hunters (Soundtrack from the Netflix Film)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('125523552',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('125523552');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'125523552');
"
track_title="Golden" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'125523552','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'125523552','0','38176338','bugs.music.listenRadioFromSeed(\'125523552\',\'track\');','N', 'Y', '_chart');
"
track_title="Golden"
artist_id="14262785"
artist_disp_nm="KPop Demon Hunters Cast"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4131460" artistId="80180886" mvId="635523" trackId="6366519" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="6366519" />
<input type="hidden" name="_isDown" value="6366519" />
<td class="check"><input type="checkbox" value="6366519" name="check" disc_id="1" title="SPAGHETTI (feat. j-hope of BTS)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>4</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4131460?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41314/4131460.jpg?version=20251028011200" onerror="bugs.utils.imgError(this);" alt="SPAGHETTI 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6366519?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6366519',true);
"
title="SPAGHETTI (feat. j-hope of BTS)" aria-label="새창">SPAGHETTI (feat. j-hope of BTS)</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/20158908?wl_ref=list_tr_10_chart" class="artistTitle" title="LE SSERAFIM (르세라핌)" >LE SSERAFIM (르세라핌)</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'LE SSERAFIM||LE SSERAFIM (르세라핌)||20158908||OK\\nj-hope||j-hope||80180886||OK', ''); return false;">
LE SSERAFIM (르세라핌)
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4131460?wl_ref=list_tr_11_chart" class="album" title="SPAGHETTI"
onclick="
">SPAGHETTI</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6366519',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6366519');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6366519');
"
track_title="SPAGHETTI (feat. j-hope of BTS)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6366519','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6366519, 635523, 'Y', 'Y', 'Y', 'Y', 6366519, 'N','OVER_12', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6366519','0','4131460','bugs.music.listenRadioFromSeed(\'6366519\',\'track\');','N', 'Y', '_chart');
"
track_title="SPAGHETTI (feat. j-hope of BTS)"
artist_id="80180886"
artist_disp_nm="j-hope"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4129960" artistId="80365655" mvId="635203" trackId="6360689" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6360689" />
<input type="hidden" name="_isDown" value="6360689" />
<td class="check"><input type="checkbox" value="6360689" name="check" disc_id="1" title="Blue Valentine" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>5</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4129960?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41299/4129960.jpg?version=20251108012458" onerror="bugs.utils.imgError(this);" alt="Blue Valentine 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6360689?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6360689',true);
"
title="Blue Valentine" aria-label="새창">Blue Valentine</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80365655?wl_ref=list_tr_10_chart" title="NMIXX"
onclick="
">NMIXX</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4129960?wl_ref=list_tr_11_chart" class="album" title="Blue Valentine"
onclick="
">Blue Valentine</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6360689',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6360689');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6360689');
"
track_title="Blue Valentine" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6360689','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6360689, 635203, 'Y', 'Y', 'Y', 'Y', 6360689, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6360689','0','4129960','bugs.music.listenRadioFromSeed(\'6360689\',\'track\');','N', 'Y', '_chart');
"
track_title="Blue Valentine"
artist_id="80365655"
artist_disp_nm="NMIXX"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4130608" artistId="80041466" mvId="635311" trackId="6361665" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6361665" />
<input type="hidden" name="_isDown" value="6361665" />
<td class="check"><input type="checkbox" value="6361665" name="check" disc_id="1" title="타임캡슐" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>6</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4130608?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41306/4130608.jpg?version=20251017094801" onerror="bugs.utils.imgError(this);" alt="타임캡슐 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6361665?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6361665',true);
"
title="타임캡슐" aria-label="새창">타임캡슐</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80041466?wl_ref=list_tr_10_chart" title="다비치"
onclick="
">다비치</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4130608?wl_ref=list_tr_11_chart" class="album" title="타임캡슐"
onclick="
">타임캡슐</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6361665',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6361665');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6361665');
"
track_title="타임캡슐" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6361665','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6361665, 635311, 'Y', 'Y', 'Y', 'Y', 6361665, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6361665','0','4130608','bugs.music.listenRadioFromSeed(\'6361665\',\'track\');','N', 'Y', '_chart');
"
track_title="타임캡슐"
artist_id="80041466"
artist_disp_nm="다비치"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="38176338" artistId="80147633" mvId="0" trackId="125523551" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="125523551" />
<input type="hidden" name="_isDown" value="125523551" />
<td class="check"><input type="checkbox" value="125523551" name="check" disc_id="1" title="Soda Pop" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>7</strong>
<p class="change up"><span class="arrow"></span> <em>5</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/381763/38176338.jpg?version=20250927005933" onerror="bugs.utils.imgError(this);" alt="KPop Demon Hunters (Soundtrack from the Netflix Film) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/125523551?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('125523551',true);
"
title="Soda Pop" aria-label="새창">Soda Pop</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/14262762?wl_ref=list_tr_10_chart" class="artistTitle" title="Saja Boys" >Saja Boys</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'Saja Boys||Saja Boys||14262762||OK\\nAndrew Choi||Andrew Choi||80147633||OK\\nNeckwav||Neckwav||20088057||OK\\nDanny Chung||Danny Chung||80258639||OK\\nKevin Woo||Kevin Woo||12979248||OK\\nsamUIL Lee||samUIL Lee||14262772||OK\\nKPop Demon Hunters Cast||KPop Demon Hunters Cast||14262785||OK', ''); return false;">
Saja Boys
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_11_chart" class="album" title="KPop Demon Hunters (Soundtrack from the Netflix Film)"
onclick="
">KPop Demon Hunters (Soundtrack from the Netflix Film)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('125523551',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('125523551');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'125523551');
"
track_title="Soda Pop" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'125523551','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'125523551','0','38176338','bugs.music.listenRadioFromSeed(\'125523551\',\'track\');','N', 'Y', '_chart');
"
track_title="Soda Pop"
artist_id="80147633"
artist_disp_nm="Andrew Choi"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4083984" artistId="80301736" mvId="0" trackId="6197438" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6197438" />
<input type="hidden" name="_isDown" value="6197438" />
<td class="check"><input type="checkbox" value="6197438" name="check" disc_id="1" title="Drowning" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>8</strong>
<p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4083984?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40839/4083984.jpg?version=20250318143138" onerror="bugs.utils.imgError(this);" alt="OO-LI 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6197438?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6197438',true);
"
title="Drowning" aria-label="새창">Drowning</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80301736?wl_ref=list_tr_10_chart" title="WOODZ"
onclick="
">WOODZ</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4083984?wl_ref=list_tr_11_chart" class="album" title="OO-LI"
onclick="
">OO-LI</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6197438',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6197438');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6197438');
"
track_title="Drowning" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6197438','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6197438','0','4083984','bugs.music.listenRadioFromSeed(\'6197438\',\'track\');','N', 'Y', '_chart');
"
track_title="Drowning"
artist_id="80301736"
artist_disp_nm="WOODZ"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4122947" artistId="20022492" mvId="633327" trackId="6323217" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6323217" />
<input type="hidden" name="_isDown" value="6323217" />
<td class="check"><input type="checkbox" value="6323217" name="check" disc_id="1" title="뛰어(JUMP)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>9</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4122947?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41229/4122947.jpg?version=20250712005750" onerror="bugs.utils.imgError(this);" alt="뛰어(JUMP) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6323217?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6323217',true);
"
title="뛰어(JUMP)" aria-label="새창">뛰어(JUMP)</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20022492?wl_ref=list_tr_10_chart" title="BLACKPINK"
onclick="
">BLACKPINK</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4122947?wl_ref=list_tr_11_chart" class="album" title="뛰어(JUMP)"
onclick="
">뛰어(JUMP)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6323217',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6323217');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6323217');
"
track_title="뛰어(JUMP)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6323217','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6323217, 633327, 'Y', 'Y', 'Y', 'Y', 6323217, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6323217','0','4122947','bugs.music.listenRadioFromSeed(\'6323217\',\'track\');','N', 'Y', '_chart');
"
track_title="뛰어(JUMP)"
artist_id="20022492"
artist_disp_nm="BLACKPINK"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4121434" artistId="80408176" mvId="632771" trackId="6316357" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6316357" />
<input type="hidden" name="_isDown" value="6316357" />
<td class="check"><input type="checkbox" value="6316357" name="check" disc_id="1" title="FAMOUS" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>10</strong>
<p class="change up"><span class="arrow"></span> <em>1</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4121434?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41214/4121434.jpg?version=20251203014837" onerror="bugs.utils.imgError(this);" alt="FAMOUS 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6316357?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6316357',true);
"
title="FAMOUS" aria-label="새창">FAMOUS</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80408176?wl_ref=list_tr_10_chart" title="ALLDAY PROJECT"
onclick="
">ALLDAY PROJECT</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4121434?wl_ref=list_tr_11_chart" class="album" title="FAMOUS"
onclick="
">FAMOUS</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6316357',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6316357');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6316357');
"
track_title="FAMOUS" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6316357','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6316357, 632771, 'Y', 'Y', 'Y', 'Y', 6316357, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6316357','0','4121434','bugs.music.listenRadioFromSeed(\'6316357\',\'track\');','N', 'Y', '_chart');
"
track_title="FAMOUS"
artist_id="80408176"
artist_disp_nm="ALLDAY PROJECT"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4122969" artistId="80203305" mvId="633745" trackId="6323868" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6323868" />
<input type="hidden" name="_isDown" value="6323868" />
<td class="check"><input type="checkbox" value="6323868" name="check" disc_id="1" title="멸종위기사랑" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>11</strong>
<p class="change down"><span class="arrow"></span> <em>3</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4122969?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41229/4122969.jpg?version=20250729020842" onerror="bugs.utils.imgError(this);" alt="EROS 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6323868?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6323868',true);
"
title="멸종위기사랑" aria-label="새창">멸종위기사랑</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80203305?wl_ref=list_tr_10_chart" title="이찬혁"
onclick="
">이찬혁</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4122969?wl_ref=list_tr_11_chart" class="album" title="EROS"
onclick="
">EROS</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6323868',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6323868');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6323868');
"
track_title="멸종위기사랑" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6323868','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6323868, 633745, 'Y', 'Y', 'Y', 'Y', 6323868, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6323868','0','4122969','bugs.music.listenRadioFromSeed(\'6323868\',\'track\');','N', 'Y', '_chart');
"
track_title="멸종위기사랑"
artist_id="80203305"
artist_disp_nm="이찬혁"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4134249" artistId="80392511" mvId="636219" trackId="6381173" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6381173" />
<input type="hidden" name="_isDown" value="6381173" />
<td class="check"><input type="checkbox" value="6381173" name="check" disc_id="1" title="NOT CUTE ANYMORE" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>12</strong>
<p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4134249?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41342/4134249.jpg?version=20251129010313" onerror="bugs.utils.imgError(this);" alt="NOT CUTE ANYMORE 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6381173?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6381173',true);
"
title="NOT CUTE ANYMORE" aria-label="새창">NOT CUTE ANYMORE</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80392511?wl_ref=list_tr_10_chart" title="아일릿(ILLIT)"
onclick="
">아일릿(ILLIT)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4134249?wl_ref=list_tr_11_chart" class="album" title="NOT CUTE ANYMORE"
onclick="
">NOT CUTE ANYMORE</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6381173',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6381173');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6381173');
"
track_title="NOT CUTE ANYMORE" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6381173','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6381173, 636219, 'Y', 'Y', 'Y', 'Y', 6381173, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6381173','0','4134249','bugs.music.listenRadioFromSeed(\'6381173\',\'track\');','N', 'Y', '_chart');
"
track_title="NOT CUTE ANYMORE"
artist_id="80392511"
artist_disp_nm="아일릿(ILLIT)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="829" artistId="1079" mvId="565602" trackId="14776" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="14776" />
<input type="hidden" name="_isDown" value="14776" />
<td class="check"><input type="checkbox" value="14776" name="check" disc_id="1" title="All I Want for Christmas Is You" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>13</strong>
<p class="change up"><span class="arrow"></span> <em>2</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/829?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/8/829.jpg?version=20251125003241" onerror="bugs.utils.imgError(this);" alt="Merry Christmas (Deluxe Anniversary Edition) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/14776?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('14776',true);
"
title="All I Want for Christmas Is You" aria-label="새창">All I Want for Christmas Is You</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/1079?wl_ref=list_tr_10_chart" title="Mariah Carey(머라이어 캐리)"
onclick="
">Mariah Carey(머라이어 캐리)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/829?wl_ref=list_tr_11_chart" class="album" title="Merry Christmas (Deluxe Anniversary Edition)"
onclick="
">Merry Christmas (Deluxe Anniversary Edition)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('14776',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('14776');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'14776');
"
track_title="All I Want for Christmas Is You" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'14776','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,14776, 565602, 'Y', 'Y', 'Y', 'Y', 100014776, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'14776','0','829','bugs.music.listenRadioFromSeed(\'14776\',\'track\');','N', 'Y', '_chart');
"
track_title="All I Want for Christmas Is You"
artist_id="1079"
artist_disp_nm="Mariah Carey(머라이어 캐리)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4115971" artistId="80265678" mvId="630887" trackId="6292518" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6292518" />
<input type="hidden" name="_isDown" value="6292518" />
<td class="check"><input type="checkbox" value="6292518" name="check" disc_id="1" title="like JENNIE" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>14</strong>
<p class="change up"><span class="arrow"></span> <em>9</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4115971?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41159/4115971.jpg?version=20250322025325" onerror="bugs.utils.imgError(this);" alt="Ruby 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6292518?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6292518',true);
"
title="like JENNIE" aria-label="새창">like JENNIE</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80265678?wl_ref=list_tr_10_chart" title="제니 (JENNIE)"
onclick="
">제니 (JENNIE)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4115971?wl_ref=list_tr_11_chart" class="album" title="Ruby"
onclick="
">Ruby</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6292518',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6292518');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6292518');
"
track_title="like JENNIE" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6292518','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6292518, 630887, 'Y', 'Y', 'Y', 'Y', 6292518, 'Y','ADULT', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6292518','0','4115971','bugs.music.listenRadioFromSeed(\'6292518\',\'track\');','N', 'Y', '_chart');
"
track_title="like JENNIE"
artist_id="80265678"
artist_disp_nm="제니 (JENNIE)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4111311" artistId="80265679" mvId="629306" trackId="6274999" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6274999" />
<input type="hidden" name="_isDown" value="6274999" />
<td class="check"><input type="checkbox" value="6274999" name="check" disc_id="1" title="toxic till the end" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>15</strong>
<p class="change up"><span class="arrow"></span> <em>4</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4111311?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41113/4111311.jpg?version=20250319100710" onerror="bugs.utils.imgError(this);" alt="rosie 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6274999?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6274999',true);
"
title="toxic till the end" aria-label="새창">toxic till the end</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80265679?wl_ref=list_tr_10_chart" title="로제(ROSÉ)"
onclick="
">로제(ROSÉ)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4111311?wl_ref=list_tr_11_chart" class="album" title="rosie"
onclick="
">rosie</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6274999',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6274999');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6274999');
"
track_title="toxic till the end" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6274999','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6274999, 629306, 'Y', 'Y', 'Y', 'Y', 6274999, 'Y','ADULT', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6274999','0','4111311','bugs.music.listenRadioFromSeed(\'6274999\',\'track\');','N', 'Y', '_chart');
"
track_title="toxic till the end"
artist_id="80265679"
artist_disp_nm="로제(ROSÉ)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4131664" artistId="80137715" mvId="635535" trackId="6367638" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6367638" />
<input type="hidden" name="_isDown" value="6367638" />
<td class="check"><input type="checkbox" value="6367638" name="check" disc_id="1" title="달리 표현할 수 없어요" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>16</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4131664?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41316/4131664.jpg?version=20251029004137" onerror="bugs.utils.imgError(this);" alt="달리 표현할 수 없어요 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6367638?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6367638',true);
"
title="달리 표현할 수 없어요" aria-label="새창">달리 표현할 수 없어요</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80137715?wl_ref=list_tr_10_chart" title="로이킴"
onclick="
">로이킴</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4131664?wl_ref=list_tr_11_chart" class="album" title="달리 표현할 수 없어요"
onclick="
">달리 표현할 수 없어요</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6367638',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6367638');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6367638');
"
track_title="달리 표현할 수 없어요" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6367638','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6367638, 635535, 'Y', 'Y', 'Y', 'Y', 6367638, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6367638','0','4131664','bugs.music.listenRadioFromSeed(\'6367638\',\'track\');','N', 'Y', '_chart');
"
track_title="달리 표현할 수 없어요"
artist_id="80137715"
artist_disp_nm="로이킴"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4128980" artistId="80405039" mvId="635393" trackId="6363774" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6363774" />
<input type="hidden" name="_isDown" value="6363774" />
<td class="check"><input type="checkbox" value="6363774" name="check" disc_id="1" title="FOCUS" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>17</strong>
<p class="change down"><span class="arrow"></span> <em>3</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4128980?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41289/4128980.jpg?version=20251022002830" onerror="bugs.utils.imgError(this);" alt="FOCUS - The 1st Mini Album 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6363774?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6363774',true);
"
title="FOCUS" aria-label="새창">FOCUS</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80405039?wl_ref=list_tr_10_chart" title="Hearts2Hearts (하츠투하츠)"
onclick="
">Hearts2Hearts (하츠투하츠)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4128980?wl_ref=list_tr_11_chart" class="album" title="FOCUS - The 1st Mini Album"
onclick="
">FOCUS - The 1st Mini Album</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6363774',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6363774');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6363774');
"
track_title="FOCUS" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6363774','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6363774, 635393, 'Y', 'Y', 'Y', 'Y', 6363774, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6363774','0','4128980','bugs.music.listenRadioFromSeed(\'6363774\',\'track\');','N', 'Y', '_chart');
"
track_title="FOCUS"
artist_id="80405039"
artist_disp_nm="Hearts2Hearts (하츠투하츠)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="400586" artistId="80155940" mvId="0" trackId="3306856" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="3306856" />
<input type="hidden" name="_isDown" value="3306856" />
<td class="check"><input type="checkbox" value="3306856" name="check" disc_id="1" title="첫 눈" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>18</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/400586?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/4005/400586.jpg?version=20250107030153" onerror="bugs.utils.imgError(this);" alt="겨울 스페셜 앨범 '12월의 기적 (Miracles in December)’ 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/3306856?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('3306856',true);
"
title="첫 눈" aria-label="새창">첫 눈</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80155940?wl_ref=list_tr_10_chart" title="EXO"
onclick="
">EXO</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/400586?wl_ref=list_tr_11_chart" class="album" title="겨울 스페셜 앨범 '12월의 기적 (Miracles in December)’"
onclick="
">겨울 스페셜 앨범 '12월의 기적 (Miracles in December)’</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('3306856',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('3306856');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'3306856');
"
track_title="첫 눈" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'3306856','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'3306856','0','400586','bugs.music.listenRadioFromSeed(\'3306856\',\'track\');','N', 'Y', '_chart');
"
track_title="첫 눈"
artist_id="80155940"
artist_disp_nm="EXO"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20677117" artistId="80137715" mvId="628092" trackId="33324182" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33324182" />
<input type="hidden" name="_isDown" value="33324182" />
<td class="check"><input type="checkbox" value="33324182" name="check" disc_id="1" title="내게 사랑이 뭐냐고 물어본다면" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>19</strong>
<p class="change up"><span class="arrow"></span> <em>10</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20677117?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/206771/20677117.jpg?version=20251125081353" onerror="bugs.utils.imgError(this);" alt="내게 사랑이 뭐냐고 물어본다면 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33324182?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33324182',true);
"
title="내게 사랑이 뭐냐고 물어본다면" aria-label="새창">내게 사랑이 뭐냐고 물어본다면</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80137715?wl_ref=list_tr_10_chart" title="로이킴"
onclick="
">로이킴</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20677117?wl_ref=list_tr_11_chart" class="album" title="내게 사랑이 뭐냐고 물어본다면"
onclick="
">내게 사랑이 뭐냐고 물어본다면</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33324182',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33324182');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33324182');
"
track_title="내게 사랑이 뭐냐고 물어본다면" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33324182','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33324182, 628092, 'Y', 'Y', 'Y', 'Y', 33324182, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33324182','0','20677117','bugs.music.listenRadioFromSeed(\'33324182\',\'track\');','N', 'Y', '_chart');
"
track_title="내게 사랑이 뭐냐고 물어본다면"
artist_id="80137715"
artist_disp_nm="로이킴"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4126044" artistId="20148657" mvId="634287" trackId="6339047" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6339047" />
<input type="hidden" name="_isDown" value="6339047" />
<td class="check"><input type="checkbox" value="6339047" name="check" disc_id="1" title="XOXZ" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>20</strong>
<p class="change down"><span class="arrow"></span> <em>3</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4126044?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41260/4126044.jpg?version=20250828003754" onerror="bugs.utils.imgError(this);" alt="IVE SECRET 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6339047?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6339047',true);
"
title="XOXZ" aria-label="새창">XOXZ</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20148657?wl_ref=list_tr_10_chart" title="IVE (아이브)"
onclick="
">IVE (아이브)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4126044?wl_ref=list_tr_11_chart" class="album" title="IVE SECRET"
onclick="
">IVE SECRET</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6339047',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6339047');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6339047');
"
track_title="XOXZ" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6339047','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6339047, 634287, 'Y', 'Y', 'Y', 'Y', 6339047, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6339047','0','4126044','bugs.music.listenRadioFromSeed(\'6339047\',\'track\');','N', 'Y', '_chart');
"
track_title="XOXZ"
artist_id="20148657"
artist_disp_nm="IVE (아이브)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20629850" artistId="80245739" mvId="0" trackId="33122825" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33122825" />
<input type="hidden" name="_isDown" value="33122825" />
<td class="check"><input type="checkbox" value="33122825" name="check" disc_id="1" title="HAPPY" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>21</strong>
<p class="change up"><span class="arrow"></span> <em>9</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20629850?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/206298/20629850.jpg?version=20250104012829" onerror="bugs.utils.imgError(this);" alt="Fourever 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33122825?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33122825',true);
"
title="HAPPY" aria-label="새창">HAPPY</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20629850?wl_ref=list_tr_11_chart" class="album" title="Fourever"
onclick="
">Fourever</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33122825',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33122825');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33122825');
"
track_title="HAPPY" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33122825','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33122825','0','20629850','bugs.music.listenRadioFromSeed(\'33122825\',\'track\');','N', 'Y', '_chart');
"
track_title="HAPPY"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20586963" artistId="20155724" mvId="0" trackId="32944687" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="32944687" />
<input type="hidden" name="_isDown" value="32944687" />
<td class="check"><input type="checkbox" value="32944687" name="check" disc_id="1" title="사랑하게 될 거야" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>22</strong>
<p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20586963?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/205869/20586963.jpg?version=20240904004214" onerror="bugs.utils.imgError(this);" alt="이상비행 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/32944687?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32944687',true);
"
title="사랑하게 될 거야" aria-label="새창">사랑하게 될 거야</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20155724?wl_ref=list_tr_10_chart" title="한로로"
onclick="
">한로로</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20586963?wl_ref=list_tr_11_chart" class="album" title="이상비행"
onclick="
">이상비행</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('32944687',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('32944687');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'32944687');
"
track_title="사랑하게 될 거야" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'32944687','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'32944687','0','20586963','bugs.music.listenRadioFromSeed(\'32944687\',\'track\');','N', 'Y', '_chart');
"
track_title="사랑하게 될 거야"
artist_id="20155724"
artist_disp_nm="한로로"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4115921" artistId="80067149" mvId="630840" trackId="6292278" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6292278" />
<input type="hidden" name="_isDown" value="6292278" />
<td class="check"><input type="checkbox" value="6292278" name="check" disc_id="1" title="너에게 닿기를" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>23</strong>
<p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4115921?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41159/4115921.jpg?version=20250307105703" onerror="bugs.utils.imgError(this);" alt="너에게 닿기를 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6292278?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6292278',true);
"
title="너에게 닿기를" aria-label="새창">너에게 닿기를</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80067149?wl_ref=list_tr_10_chart" title="10CM"
onclick="
">10CM</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4115921?wl_ref=list_tr_11_chart" class="album" title="너에게 닿기를"
onclick="
">너에게 닿기를</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6292278',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6292278');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6292278');
"
track_title="너에게 닿기를" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6292278','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6292278, 630840, 'Y', 'Y', 'Y', 'Y', 6292278, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6292278','0','4115921','bugs.music.listenRadioFromSeed(\'6292278\',\'track\');','N', 'Y', '_chart');
"
track_title="너에게 닿기를"
artist_id="80067149"
artist_disp_nm="10CM"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4112579" artistId="13081729" mvId="629803" trackId="6280276" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6280276" />
<input type="hidden" name="_isDown" value="6280276" />
<td class="check"><input type="checkbox" value="6280276" name="check" disc_id="1" title="모르시나요(PROD.로코베리)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>24</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4112579?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41125/4112579.jpg?version=20250108003805" onerror="bugs.utils.imgError(this);" alt="모르시나요 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6280276?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6280276',true);
"
title="모르시나요(PROD.로코베리)" aria-label="새창">모르시나요(PROD.로코베리)</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/13081729?wl_ref=list_tr_10_chart" title="조째즈"
onclick="
">조째즈</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4112579?wl_ref=list_tr_11_chart" class="album" title="모르시나요"
onclick="
">모르시나요</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6280276',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6280276');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6280276');
"
track_title="모르시나요(PROD.로코베리)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6280276','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6280276, 629803, 'Y', 'Y', 'Y', 'Y', 6280276, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6280276','0','4112579','bugs.music.listenRadioFromSeed(\'6280276\',\'track\');','N', 'Y', '_chart');
"
track_title="모르시나요(PROD.로코베리)"
artist_id="13081729"
artist_disp_nm="조째즈"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4127586" artistId="80257365" mvId="634632" trackId="6344700" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6344700" />
<input type="hidden" name="_isDown" value="6344700" />
<td class="check"><input type="checkbox" value="6344700" name="check" disc_id="1" title="body" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>25</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4127586?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41275/4127586.jpg?version=20250923011626" onerror="bugs.utils.imgError(this);" alt="gonna love me, right? 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6344700?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6344700',true);
"
title="body" aria-label="새창">body</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80257365?wl_ref=list_tr_10_chart" title="다영 (DAYOUNG)"
onclick="
">다영 (DAYOUNG)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4127586?wl_ref=list_tr_11_chart" class="album" title="gonna love me, right?"
onclick="
">gonna love me, right?</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6344700',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6344700');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6344700');
"
track_title="body" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6344700','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6344700, 634632, 'Y', 'Y', 'Y', 'Y', 6344700, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6344700','0','4127586','bugs.music.listenRadioFromSeed(\'6344700\',\'track\');','N', 'Y', '_chart');
"
track_title="body"
artist_id="80257365"
artist_disp_nm="다영 (DAYOUNG)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4134802" artistId="80026437" mvId="636361" trackId="6384173" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6384173" />
<input type="hidden" name="_isDown" value="6384173" />
<td class="check"><input type="checkbox" value="6384173" name="check" disc_id="1" title="인사 (Panorama)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>26</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4134802?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41348/4134802.jpg?version=20251202011149" onerror="bugs.utils.imgError(this);" alt="Panorama : The Best of TAEYEON 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6384173?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6384173',true);
"
title="인사 (Panorama)" aria-label="새창">인사 (Panorama)</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80026437?wl_ref=list_tr_10_chart" title="태연 (TAEYEON)"
onclick="
">태연 (TAEYEON)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4134802?wl_ref=list_tr_11_chart" class="album" title="Panorama : The Best of TAEYEON"
onclick="
">Panorama : The Best of TAEYEON</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6384173',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6384173');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6384173');
"
track_title="인사 (Panorama)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6384173','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6384173, 636361, 'Y', 'Y', 'Y', 'Y', 6384173, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6384173','0','4134802','bugs.music.listenRadioFromSeed(\'6384173\',\'track\');','N', 'Y', '_chart');
"
track_title="인사 (Panorama)"
artist_id="80026437"
artist_disp_nm="태연 (TAEYEON)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4108755" artistId="80347326" mvId="628217" trackId="6266734" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6266734" />
<input type="hidden" name="_isDown" value="6266734" />
<td class="check"><input type="checkbox" value="6266734" name="check" disc_id="1" title="Whiplash" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>27</strong>
<p class="change down"><span class="arrow"></span> <em>6</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4108755?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41087/4108755.jpg?version=20241126004739" onerror="bugs.utils.imgError(this);" alt="Whiplash - The 5th Mini Album 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6266734?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6266734',true);
"
title="Whiplash" aria-label="새창">Whiplash</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80347326?wl_ref=list_tr_10_chart" title="aespa"
onclick="
">aespa</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4108755?wl_ref=list_tr_11_chart" class="album" title="Whiplash - The 5th Mini Album"
onclick="
">Whiplash - The 5th Mini Album</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6266734',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6266734');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6266734');
"
track_title="Whiplash" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6266734','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6266734, 628217, 'Y', 'Y', 'Y', 'Y', 6266734, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6266734','0','4108755','bugs.music.listenRadioFromSeed(\'6266734\',\'track\');','N', 'Y', '_chart');
"
track_title="Whiplash"
artist_id="80347326"
artist_disp_nm="aespa"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20265759" artistId="80245739" mvId="525611" trackId="31650949" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="31650949" />
<input type="hidden" name="_isDown" value="31650949" />
<td class="check"><input type="checkbox" value="31650949" name="check" disc_id="1" title="한 페이지가 될 수 있게" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>28</strong>
<p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20265759?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/202657/20265759.jpg?version=20211119004415" onerror="bugs.utils.imgError(this);" alt="The Book of Us : Gravity 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/31650949?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31650949',true);
"
title="한 페이지가 될 수 있게" aria-label="새창">한 페이지가 될 수 있게</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20265759?wl_ref=list_tr_11_chart" class="album" title="The Book of Us : Gravity"
onclick="
">The Book of Us : Gravity</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('31650949',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('31650949');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'31650949');
"
track_title="한 페이지가 될 수 있게" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'31650949','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,31650949, 525611, 'Y', 'Y', 'Y', 'Y', 31650949, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'31650949','0','20265759','bugs.music.listenRadioFromSeed(\'31650949\',\'track\');','N', 'Y', '_chart');
"
track_title="한 페이지가 될 수 있게"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20629850" artistId="80245739" mvId="623721" trackId="33122824" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33122824" />
<input type="hidden" name="_isDown" value="33122824" />
<td class="check"><input type="checkbox" value="33122824" name="check" disc_id="1" title="Welcome to the Show" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>29</strong>
<p class="change up"><span class="arrow"></span> <em>8</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20629850?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/206298/20629850.jpg?version=20250104012829" onerror="bugs.utils.imgError(this);" alt="Fourever 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33122824?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33122824',true);
"
title="Welcome to the Show" aria-label="새창">Welcome to the Show</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20629850?wl_ref=list_tr_11_chart" class="album" title="Fourever"
onclick="
">Fourever</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33122824',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33122824');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33122824');
"
track_title="Welcome to the Show" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33122824','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33122824, 623721, 'Y', 'N', 'Y', 'Y', 33122824, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33122824','0','20629850','bugs.music.listenRadioFromSeed(\'33122824\',\'track\');','N', 'Y', '_chart');
"
track_title="Welcome to the Show"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4108664" artistId="80072173" mvId="628182" trackId="6266460" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="6266460" />
<input type="hidden" name="_isDown" value="6266460" />
<td class="check"><input type="checkbox" value="6266460" name="check" disc_id="1" title="APT." buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>30</strong>
<p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4108664?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41086/4108664.jpg?version=20241206010201" onerror="bugs.utils.imgError(this);" alt="APT. 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6266460?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6266460',true);
"
title="APT." aria-label="새창">APT.</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/80265679?wl_ref=list_tr_10_chart" class="artistTitle" title="로제(ROSÉ)" >로제(ROSÉ)</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, '로제||로제(ROSÉ)||80265679||OK\\nBruno Mars||Bruno Mars(브루노 마스)||80072173||OK', ''); return false;">
로제(ROSÉ)
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4108664?wl_ref=list_tr_11_chart" class="album" title="APT."
onclick="
">APT.</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6266460',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6266460');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6266460');
"
track_title="APT." class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6266460','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6266460, 628182, 'Y', 'Y', 'Y', 'Y', 6266460, 'N','OVER_12', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6266460','0','4108664','bugs.music.listenRadioFromSeed(\'6266460\',\'track\');','N', 'Y', '_chart');
"
track_title="APT."
artist_id="80072173"
artist_disp_nm="Bruno Mars(브루노 마스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4108756" artistId="80145846" mvId="0" trackId="6266740" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6266740" />
<input type="hidden" name="_isDown" value="6266740" />
<td class="check"><input type="checkbox" value="6266740" name="check" disc_id="1" title="나는 반딧불" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>31</strong>
<p class="change up"><span class="arrow"></span> <em>18</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4108756?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41087/4108756.jpg?version=20241023010353" onerror="bugs.utils.imgError(this);" alt="나는 반딧불 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6266740?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6266740',true);
"
title="나는 반딧불" aria-label="새창">나는 반딧불</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80145846?wl_ref=list_tr_10_chart" title="황가람"
onclick="
">황가람</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4108756?wl_ref=list_tr_11_chart" class="album" title="나는 반딧불"
onclick="
">나는 반딧불</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6266740',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6266740');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6266740');
"
track_title="나는 반딧불" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6266740','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6266740','0','4108756','bugs.music.listenRadioFromSeed(\'6266740\',\'track\');','N', 'Y', '_chart');
"
track_title="나는 반딧불"
artist_id="80145846"
artist_disp_nm="황가람"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20774246" artistId="20047596" mvId="636368" trackId="33764436" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33764436" />
<input type="hidden" name="_isDown" value="33764436" />
<td class="check"><input type="checkbox" value="33764436" name="check" disc_id="1" title="하얀 그리움" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>32</strong>
<p class="change up"><span class="arrow"></span> <em>2</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20774246?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/207742/20774246.jpg?version=20251203012355" onerror="bugs.utils.imgError(this);" alt="하얀 그리움 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33764436?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33764436',true);
"
title="하얀 그리움" aria-label="새창">하얀 그리움</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20047596?wl_ref=list_tr_10_chart" title="프로미스나인"
onclick="
">프로미스나인</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20774246?wl_ref=list_tr_11_chart" class="album" title="하얀 그리움"
onclick="
">하얀 그리움</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33764436',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33764436');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33764436');
"
track_title="하얀 그리움" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33764436','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33764436, 636368, 'Y', 'Y', 'Y', 'Y', 33764436, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33764436','0','20774246','bugs.music.listenRadioFromSeed(\'33764436\',\'track\');','N', 'Y', '_chart');
"
track_title="하얀 그리움"
artist_id="20047596"
artist_disp_nm="프로미스나인"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4121434" artistId="80408176" mvId="632922" trackId="6318286" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6318286" />
<input type="hidden" name="_isDown" value="6318286" />
<td class="check"><input type="checkbox" value="6318286" name="check" disc_id="1" title="WICKED" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>33</strong>
<p class="change up"><span class="arrow"></span> <em>5</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4121434?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41214/4121434.jpg?version=20251203014837" onerror="bugs.utils.imgError(this);" alt="FAMOUS 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6318286?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6318286',true);
"
title="WICKED" aria-label="새창">WICKED</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80408176?wl_ref=list_tr_10_chart" title="ALLDAY PROJECT"
onclick="
">ALLDAY PROJECT</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4121434?wl_ref=list_tr_11_chart" class="album" title="FAMOUS"
onclick="
">FAMOUS</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6318286',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6318286');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6318286');
"
track_title="WICKED" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6318286','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6318286, 632922, 'Y', 'Y', 'Y', 'Y', 6318286, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6318286','0','4121434','bugs.music.listenRadioFromSeed(\'6318286\',\'track\');','N', 'Y', '_chart');
"
track_title="WICKED"
artist_id="80408176"
artist_disp_nm="ALLDAY PROJECT"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4108180" artistId="20056684" mvId="627945" trackId="6265038" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6265038" />
<input type="hidden" name="_isDown" value="6265038" />
<td class="check"><input type="checkbox" value="6265038" name="check" disc_id="1" title="청춘만화" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>34</strong>
<p class="change down"><span class="arrow"></span> <em>3</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4108180?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41081/4108180.jpg?version=20250318024429" onerror="bugs.utils.imgError(this);" alt="만화 (滿花) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6265038?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6265038',true);
"
title="청춘만화" aria-label="새창">청춘만화</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20056684?wl_ref=list_tr_10_chart" title="이무진"
onclick="
">이무진</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4108180?wl_ref=list_tr_11_chart" class="album" title="만화 (滿花)"
onclick="
">만화 (滿花)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6265038',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6265038');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6265038');
"
track_title="청춘만화" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6265038','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6265038, 627945, 'Y', 'Y', 'Y', 'Y', 6265038, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6265038','0','4108180','bugs.music.listenRadioFromSeed(\'6265038\',\'track\');','N', 'Y', '_chart');
"
track_title="청춘만화"
artist_id="20056684"
artist_disp_nm="이무진"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4124853" artistId="20009763" mvId="0" trackId="6332722" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="6332722" />
<input type="hidden" name="_isDown" value="6332722" />
<td class="check"><input type="checkbox" value="6332722" name="check" disc_id="1" title="시작의 아이 ❍" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>35</strong>
<p class="change up"><span class="arrow"></span> <em>4</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4124853?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41248/4124853.jpg?version=20250812013338" onerror="bugs.utils.imgError(this);" alt="시작의 아이 ❍ ハジマリのコ Starting With You : ♡ 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6332722?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6332722',true);
"
title="시작의 아이 ❍" aria-label="새창">시작의 아이 ❍</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/20009763?wl_ref=list_tr_10_chart" class="artistTitle" title="박다혜" >박다혜</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, '박다혜||박다혜||20009763||OK\\n마크툽||마크툽(MAKTUB)||80109484||OK', ''); return false;">
박다혜
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4124853?wl_ref=list_tr_11_chart" class="album" title="시작의 아이 ❍ ハジマリのコ Starting With You : ♡"
onclick="
">시작의 아이 ❍ ハジマリのコ Starting With You : ♡</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6332722',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6332722');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6332722');
"
track_title="시작의 아이 ❍" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6332722','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6332722','0','4124853','bugs.music.listenRadioFromSeed(\'6332722\',\'track\');','N', 'Y', '_chart');
"
track_title="시작의 아이 ❍"
artist_id="20009763"
artist_disp_nm="박다혜"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4134923" artistId="20249157" mvId="636411" trackId="6384880" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6384880" />
<input type="hidden" name="_isDown" value="6384880" />
<td class="check"><input type="checkbox" value="6384880" name="check" disc_id="1" title="UxYOUxU" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>36</strong>
<p class="change down"><span class="arrow"></span> <em>23</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4134923?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41349/4134923.jpg?version=20251205014941" onerror="bugs.utils.imgError(this);" alt="SWEET DREAM 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6384880?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6384880',true);
"
title="UxYOUxU" aria-label="새창">UxYOUxU</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20249157?wl_ref=list_tr_10_chart" title="최립우 (CHUEI LI YU)"
onclick="
">최립우 (CHUEI LI YU)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4134923?wl_ref=list_tr_11_chart" class="album" title="SWEET DREAM"
onclick="
">SWEET DREAM</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6384880',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6384880');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6384880');
"
track_title="UxYOUxU" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6384880','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6384880, 636411, 'Y', 'Y', 'Y', 'Y', 6384880, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6384880','0','4134923','bugs.music.listenRadioFromSeed(\'6384880\',\'track\');','N', 'Y', '_chart');
"
track_title="UxYOUxU"
artist_id="20249157"
artist_disp_nm="최립우 (CHUEI LI YU)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4113098" artistId="20148657" mvId="629973" trackId="6281197" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6281197" />
<input type="hidden" name="_isDown" value="6281197" />
<td class="check"><input type="checkbox" value="6281197" name="check" disc_id="1" title="REBEL HEART" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>37</strong>
<p class="change up"><span class="arrow"></span> <em>3</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4113098?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41130/4113098.jpg?version=20250213010511" onerror="bugs.utils.imgError(this);" alt="IVE EMPATHY 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6281197?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6281197',true);
"
title="REBEL HEART" aria-label="새창">REBEL HEART</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20148657?wl_ref=list_tr_10_chart" title="IVE (아이브)"
onclick="
">IVE (아이브)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4113098?wl_ref=list_tr_11_chart" class="album" title="IVE EMPATHY"
onclick="
">IVE EMPATHY</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6281197',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6281197');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6281197');
"
track_title="REBEL HEART" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6281197','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6281197, 629973, 'Y', 'Y', 'Y', 'Y', 6281197, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6281197','0','4113098','bugs.music.listenRadioFromSeed(\'6281197\',\'track\');','N', 'Y', '_chart');
"
track_title="REBEL HEART"
artist_id="20148657"
artist_disp_nm="IVE (아이브)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20154722" artistId="80178689" mvId="0" trackId="30994623" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="30994623" />
<input type="hidden" name="_isDown" value="30994623" />
<td class="check"><input type="checkbox" value="30994623" name="check" disc_id="1" title="모든 날, 모든 순간 (Every day, Every Moment)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>38</strong>
<p class="change down"><span class="arrow"></span> <em>6</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20154722?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/201547/20154722.jpg?version=20230601001519" onerror="bugs.utils.imgError(this);" alt="'키스 먼저 할까요?' OST Part.3 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/30994623?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30994623',true);
"
title="모든 날, 모든 순간 (Every day, Every Moment)" aria-label="새창">모든 날, 모든 순간 (Every day, Every Moment)</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80178689?wl_ref=list_tr_10_chart" title="폴킴(Paul Kim)"
onclick="
">폴킴(Paul Kim)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20154722?wl_ref=list_tr_11_chart" class="album" title="'키스 먼저 할까요?' OST Part.3"
onclick="
">'키스 먼저 할까요?' OST Part.3</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30994623',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30994623');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30994623');
"
track_title="모든 날, 모든 순간 (Every day, Every Moment)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30994623','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'30994623','0','20154722','bugs.music.listenRadioFromSeed(\'30994623\',\'track\');','N', 'Y', '_chart');
"
track_title="모든 날, 모든 순간 (Every day, Every Moment)"
artist_id="80178689"
artist_disp_nm="폴킴(Paul Kim)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4127287" artistId="80347326" mvId="634551" trackId="6343455" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6343455" />
<input type="hidden" name="_isDown" value="6343455" />
<td class="check"><input type="checkbox" value="6343455" name="check" disc_id="1" title="Rich Man" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>39</strong>
<p class="change up"><span class="arrow"></span> <em>8</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4127287?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41272/4127287.jpg?version=20251023002442" onerror="bugs.utils.imgError(this);" alt="Rich Man - The 6th Mini Album 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6343455?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6343455',true);
"
title="Rich Man" aria-label="새창">Rich Man</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80347326?wl_ref=list_tr_10_chart" title="aespa"
onclick="
">aespa</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4127287?wl_ref=list_tr_11_chart" class="album" title="Rich Man - The 6th Mini Album"
onclick="
">Rich Man - The 6th Mini Album</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6343455',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6343455');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6343455');
"
track_title="Rich Man" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6343455','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6343455, 634551, 'Y', 'Y', 'Y', 'Y', 6343455, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6343455','0','4127287','bugs.music.listenRadioFromSeed(\'6343455\',\'track\');','N', 'Y', '_chart');
"
track_title="Rich Man"
artist_id="80347326"
artist_disp_nm="aespa"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20278851" artistId="80141499" mvId="547690" trackId="31708907" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="31708907" />
<input type="hidden" name="_isDown" value="31708907" />
<td class="check"><input type="checkbox" value="31708907" name="check" disc_id="1" title="어떻게 이별까지 사랑하겠어, 널 사랑하는 거지" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>40</strong>
<p class="change down"><span class="arrow"></span> <em>5</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20278851?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/202788/20278851.jpg?version=20210727012601" onerror="bugs.utils.imgError(this);" alt="항해 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/31708907?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31708907',true);
"
title="어떻게 이별까지 사랑하겠어, 널 사랑하는 거지" aria-label="새창">어떻게 이별까지 사랑하겠어, 널 사랑하는 거지</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80141499?wl_ref=list_tr_10_chart" title="AKMU(악뮤)"
onclick="
">AKMU(악뮤)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20278851?wl_ref=list_tr_11_chart" class="album" title="항해"
onclick="
">항해</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('31708907',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('31708907');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'31708907');
"
track_title="어떻게 이별까지 사랑하겠어, 널 사랑하는 거지" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'31708907','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,31708907, 547690, 'Y', 'Y', 'Y', 'Y', 31708907, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'31708907','0','20278851','bugs.music.listenRadioFromSeed(\'31708907\',\'track\');','N', 'Y', '_chart');
"
track_title="어떻게 이별까지 사랑하겠어, 널 사랑하는 거지"
artist_id="80141499"
artist_disp_nm="AKMU(악뮤)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="35613643" artistId="80046429" mvId="0" trackId="116131843" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="116131843" />
<input type="hidden" name="_isDown" value="116131843" />
<td class="check"><input type="checkbox" value="116131843" name="check" disc_id="1" title="Die With A Smile" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>41</strong>
<p class="change up"><span class="arrow"></span> <em>20</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/35613643?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/356136/35613643.jpg?version=20250701002559" onerror="bugs.utils.imgError(this);" alt="Die With A Smile 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/116131843?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('116131843',true);
"
title="Die With A Smile" aria-label="새창">Die With A Smile</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/80046429?wl_ref=list_tr_10_chart" class="artistTitle" title="Lady Gaga(레이디 가가)" >Lady Gaga(레이디 가가)</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'Lady Gaga||Lady Gaga(레이디 가가)||80046429||OK\\nBruno Mars||Bruno Mars(브루노 마스)||80072173||OK', ''); return false;">
Lady Gaga(레이디 가가)
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/35613643?wl_ref=list_tr_11_chart" class="album" title="Die With A Smile"
onclick="
">Die With A Smile</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('116131843',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('116131843');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'116131843');
"
track_title="Die With A Smile" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'116131843','true','true','44.1','false','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'116131843','0','35613643','bugs.music.listenRadioFromSeed(\'116131843\',\'track\');','N', 'Y', '_chart');
"
track_title="Die With A Smile"
artist_id="80046429"
artist_disp_nm="Lady Gaga(레이디 가가)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="38176338" artistId="14262762" mvId="0" trackId="125523555" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="125523555" />
<input type="hidden" name="_isDown" value="125523555" />
<td class="check"><input type="checkbox" value="125523555" name="check" disc_id="1" title="Your Idol" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>42</strong>
<p class="change down"><span class="arrow"></span> <em>9</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/381763/38176338.jpg?version=20250927005933" onerror="bugs.utils.imgError(this);" alt="KPop Demon Hunters (Soundtrack from the Netflix Film) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/125523555?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('125523555',true);
"
title="Your Idol" aria-label="새창">Your Idol</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/14262762?wl_ref=list_tr_10_chart" class="artistTitle" title="Saja Boys" >Saja Boys</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'Saja Boys||Saja Boys||14262762||OK\\nAndrew Choi||Andrew Choi||80147633||OK\\nNeckwav||Neckwav||20088057||OK\\nDanny Chung||Danny Chung||80258639||OK\\nKevin Woo||Kevin Woo||12979248||OK\\nsamUIL Lee||samUIL Lee||14262772||OK\\nKPop Demon Hunters Cast||KPop Demon Hunters Cast||14262785||OK', ''); return false;">
Saja Boys
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_11_chart" class="album" title="KPop Demon Hunters (Soundtrack from the Netflix Film)"
onclick="
">KPop Demon Hunters (Soundtrack from the Netflix Film)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('125523555',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('125523555');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'125523555');
"
track_title="Your Idol" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'125523555','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'125523555','0','38176338','bugs.music.listenRadioFromSeed(\'125523555\',\'track\');','N', 'Y', '_chart');
"
track_title="Your Idol"
artist_id="14262762"
artist_disp_nm="Saja Boys"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="465672" artistId="80117591" mvId="251830" trackId="3778011" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="3778011" />
<input type="hidden" name="_isDown" value="3778011" />
<td class="check"><input type="checkbox" value="3778011" name="check" disc_id="1" title="Santa Tell Me" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>43</strong>
<p class="change down"><span class="arrow"></span> <em>7</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/465672?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/4656/465672.jpg?version=20241212013111" onerror="bugs.utils.imgError(this);" alt="Santa Tell Me 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/3778011?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('3778011',true);
"
title="Santa Tell Me" aria-label="새창">Santa Tell Me</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80117591?wl_ref=list_tr_10_chart" title="Ariana Grande(아리아나 그란데)"
onclick="
">Ariana Grande(아리아나 그란데)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/465672?wl_ref=list_tr_11_chart" class="album" title="Santa Tell Me"
onclick="
">Santa Tell Me</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('3778011',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('3778011');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'3778011');
"
track_title="Santa Tell Me" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'3778011','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,3778011, 251830, 'Y', 'Y', 'Y', 'Y', 103778011, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'3778011','0','465672','bugs.music.listenRadioFromSeed(\'3778011\',\'track\');','N', 'Y', '_chart');
"
track_title="Santa Tell Me"
artist_id="80117591"
artist_disp_nm="Ariana Grande(아리아나 그란데)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20632324" artistId="80392511" mvId="623863" trackId="33133208" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33133208" />
<input type="hidden" name="_isDown" value="33133208" />
<td class="check"><input type="checkbox" value="33133208" name="check" disc_id="1" title="Magnetic" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>44</strong>
<p class="change up"><span class="arrow"></span> <em>6</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20632324?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/206323/20632324.jpg?version=20251125080152" onerror="bugs.utils.imgError(this);" alt="SUPER REAL ME 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33133208?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33133208',true);
"
title="Magnetic" aria-label="새창">Magnetic</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80392511?wl_ref=list_tr_10_chart" title="아일릿(ILLIT)"
onclick="
">아일릿(ILLIT)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20632324?wl_ref=list_tr_11_chart" class="album" title="SUPER REAL ME"
onclick="
">SUPER REAL ME</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33133208',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33133208');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33133208');
"
track_title="Magnetic" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33133208','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33133208, 623863, 'Y', 'Y', 'Y', 'Y', 33133208, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33133208','0','20632324','bugs.music.listenRadioFromSeed(\'33133208\',\'track\');','N', 'Y', '_chart');
"
track_title="Magnetic"
artist_id="80392511"
artist_disp_nm="아일릿(ILLIT)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4096392" artistId="80123432" mvId="0" trackId="6234453" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6234453" />
<input type="hidden" name="_isDown" value="6234453" />
<td class="check"><input type="checkbox" value="6234453" name="check" disc_id="1" title="천상연" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>45</strong>
<p class="change down"><span class="arrow"></span> <em>3</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4096392?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40963/4096392.jpg?version=20240222064728" onerror="bugs.utils.imgError(this);" alt="천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB)) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6234453?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6234453',true);
"
title="천상연" aria-label="새창">천상연</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80123432?wl_ref=list_tr_10_chart" title="이창섭"
onclick="
">이창섭</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4096392?wl_ref=list_tr_11_chart" class="album" title="천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB))"
onclick="
">천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB))</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6234453',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6234453');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6234453');
"
track_title="천상연" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6234453','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6234453','0','4096392','bugs.music.listenRadioFromSeed(\'6234453\',\'track\');','N', 'Y', '_chart');
"
track_title="천상연"
artist_id="80123432"
artist_disp_nm="이창섭"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4110641" artistId="80265679" mvId="628976" trackId="6272275" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6272275" />
<input type="hidden" name="_isDown" value="6272275" />
<td class="check"><input type="checkbox" value="6272275" name="check" disc_id="1" title="number one girl" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>46</strong>
<p class="change up"><span class="arrow"></span> <em>5</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4110641?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41106/4110641.jpg?version=20241123003542" onerror="bugs.utils.imgError(this);" alt="number one girl 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6272275?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6272275',true);
"
title="number one girl" aria-label="새창">number one girl</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80265679?wl_ref=list_tr_10_chart" title="로제(ROSÉ)"
onclick="
">로제(ROSÉ)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4110641?wl_ref=list_tr_11_chart" class="album" title="number one girl"
onclick="
">number one girl</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6272275',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6272275');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6272275');
"
track_title="number one girl" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6272275','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6272275, 628976, 'Y', 'N', 'N', 'Y', 6272275, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6272275','0','4110641','bugs.music.listenRadioFromSeed(\'6272275\',\'track\');','N', 'Y', '_chart');
"
track_title="number one girl"
artist_id="80265679"
artist_disp_nm="로제(ROSÉ)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4121497" artistId="80405039" mvId="632844" trackId="6316614" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6316614" />
<input type="hidden" name="_isDown" value="6316614" />
<td class="check"><input type="checkbox" value="6316614" name="check" disc_id="1" title="STYLE" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>47</strong>
<p class="change up"><span class="arrow"></span> <em>12</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4121497?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41214/4121497.jpg?version=20250619013108" onerror="bugs.utils.imgError(this);" alt="STYLE 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6316614?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6316614',true);
"
title="STYLE" aria-label="새창">STYLE</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80405039?wl_ref=list_tr_10_chart" title="Hearts2Hearts (하츠투하츠)"
onclick="
">Hearts2Hearts (하츠투하츠)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4121497?wl_ref=list_tr_11_chart" class="album" title="STYLE"
onclick="
">STYLE</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6316614',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6316614');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6316614');
"
track_title="STYLE" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6316614','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6316614, 632844, 'Y', 'Y', 'Y', 'Y', 6316614, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6316614','0','4121497','bugs.music.listenRadioFromSeed(\'6316614\',\'track\');','N', 'Y', '_chart');
"
track_title="STYLE"
artist_id="80405039"
artist_disp_nm="Hearts2Hearts (하츠투하츠)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4121023" artistId="80392511" mvId="632783" trackId="6316283" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6316283" />
<input type="hidden" name="_isDown" value="6316283" />
<td class="check"><input type="checkbox" value="6316283" name="check" disc_id="1" title="빌려온 고양이 (Do the Dance)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>48</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4121023?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41210/4121023.jpg?version=20251125051317" onerror="bugs.utils.imgError(this);" alt="bomb 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6316283?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6316283',true);
"
title="빌려온 고양이 (Do the Dance)" aria-label="새창">빌려온 고양이 (Do the Dance)</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80392511?wl_ref=list_tr_10_chart" title="아일릿(ILLIT)"
onclick="
">아일릿(ILLIT)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4121023?wl_ref=list_tr_11_chart" class="album" title="bomb"
onclick="
">bomb</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6316283',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6316283');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6316283');
"
track_title="빌려온 고양이 (Do the Dance)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6316283','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6316283, 632783, 'Y', 'Y', 'Y', 'Y', 6316283, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6316283','0','4121023','bugs.music.listenRadioFromSeed(\'6316283\',\'track\');','N', 'Y', '_chart');
"
track_title="빌려온 고양이 (Do the Dance)"
artist_id="80392511"
artist_disp_nm="아일릿(ILLIT)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4099653" artistId="13456593" mvId="624063" trackId="6239511" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6239511" />
<input type="hidden" name="_isDown" value="6239511" />
<td class="check"><input type="checkbox" value="6239511" name="check" disc_id="1" title="고민중독" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>49</strong>
<p class="change down"><span class="arrow"></span> <em>6</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4099653?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40996/4099653.jpg?version=20240402065258" onerror="bugs.utils.imgError(this);" alt="1st Mini Album 'MANITO' 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6239511?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6239511',true);
"
title="고민중독" aria-label="새창">고민중독</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/13456593?wl_ref=list_tr_10_chart" title="QWER"
onclick="
">QWER</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4099653?wl_ref=list_tr_11_chart" class="album" title="1st Mini Album 'MANITO'"
onclick="
">1st Mini Album 'MANITO'</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6239511',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6239511');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6239511');
"
track_title="고민중독" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6239511','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6239511, 624063, 'Y', 'Y', 'Y', 'Y', 6239511, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6239511','0','4099653','bugs.music.listenRadioFromSeed(\'6239511\',\'track\');','N', 'Y', '_chart');
"
track_title="고민중독"
artist_id="13456593"
artist_disp_nm="QWER"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4101141" artistId="80347326" mvId="625019" trackId="6245033" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6245033" />
<input type="hidden" name="_isDown" value="6245033" />
<td class="check"><input type="checkbox" value="6245033" name="check" disc_id="1" title="Supernova" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>50</strong>
<p class="change up"><span class="arrow"></span> <em>5</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4101141?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41011/4101141.jpg?version=20241102010939" onerror="bugs.utils.imgError(this);" alt="Armageddon - The 1st Album 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6245033?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6245033',true);
"
title="Supernova" aria-label="새창">Supernova</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80347326?wl_ref=list_tr_10_chart" title="aespa"
onclick="
">aespa</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4101141?wl_ref=list_tr_11_chart" class="album" title="Armageddon - The 1st Album"
onclick="
">Armageddon - The 1st Album</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6245033',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6245033');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6245033');
"
track_title="Supernova" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6245033','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6245033, 625019, 'Y', 'Y', 'Y', 'Y', 6245033, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6245033','0','4101141','bugs.music.listenRadioFromSeed(\'6245033\',\'track\');','N', 'Y', '_chart');
"
track_title="Supernova"
artist_id="80347326"
artist_disp_nm="aespa"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4094127" artistId="20056684" mvId="621845" trackId="6225822" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6225822" />
<input type="hidden" name="_isDown" value="6225822" />
<td class="check"><input type="checkbox" value="6225822" name="check" disc_id="1" title="에피소드" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>51</strong>
<p class="change up"><span class="arrow"></span> <em>40</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4094127?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40941/4094127.jpg?version=20250101001125" onerror="bugs.utils.imgError(this);" alt="에피소드 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6225822?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6225822',true);
"
title="에피소드" aria-label="새창">에피소드</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20056684?wl_ref=list_tr_10_chart" title="이무진"
onclick="
">이무진</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4094127?wl_ref=list_tr_11_chart" class="album" title="에피소드"
onclick="
">에피소드</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6225822',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6225822');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6225822');
"
track_title="에피소드" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6225822','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6225822, 621845, 'Y', 'Y', 'Y', 'Y', 6225822, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6225822','0','4094127','bugs.music.listenRadioFromSeed(\'6225822\',\'track\');','N', 'Y', '_chart');
"
track_title="에피소드"
artist_id="20056684"
artist_disp_nm="이무진"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="38176338" artistId="80332178" mvId="0" trackId="125523550" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="125523550" />
<input type="hidden" name="_isDown" value="125523550" />
<td class="check"><input type="checkbox" value="125523550" name="check" disc_id="1" title="How It’s Done" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>52</strong>
<p class="change down"><span class="arrow"></span> <em>8</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/381763/38176338.jpg?version=20250927005933" onerror="bugs.utils.imgError(this);" alt="KPop Demon Hunters (Soundtrack from the Netflix Film) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/125523550?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('125523550',true);
"
title="How It’s Done" aria-label="새창">How It’s Done</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/80408375?wl_ref=list_tr_10_chart" class="artistTitle" title="HUNTR/X" >HUNTR/X</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'HUNTR/X||HUNTR/X||80408375||OK\\nEJAE||EJAE||20021140||OK\\nAUDREY NUNA||AUDREY NUNA||80332178||OK\\nREI AMI||REI AMI||20089314||OK\\nKPop Demon Hunters Cast||KPop Demon Hunters Cast||14262785||OK', ''); return false;">
HUNTR/X
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_11_chart" class="album" title="KPop Demon Hunters (Soundtrack from the Netflix Film)"
onclick="
">KPop Demon Hunters (Soundtrack from the Netflix Film)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('125523550',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('125523550');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'125523550');
"
track_title="How It’s Done" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'125523550','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'125523550','0','38176338','bugs.music.listenRadioFromSeed(\'125523550\',\'track\');','N', 'Y', '_chart');
"
track_title="How It’s Done"
artist_id="80332178"
artist_disp_nm="AUDREY NUNA"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4084947" artistId="20148657" mvId="616170" trackId="6195812" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6195812" />
<input type="hidden" name="_isDown" value="6195812" />
<td class="check"><input type="checkbox" value="6195812" name="check" disc_id="1" title="I AM" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>53</strong>
<p class="change up"><span class="arrow"></span> <em>13</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4084947?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40849/4084947.jpg?version=20240810012634" onerror="bugs.utils.imgError(this);" alt="I've IVE 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6195812?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6195812',true);
"
title="I AM" aria-label="새창">I AM</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20148657?wl_ref=list_tr_10_chart" title="IVE (아이브)"
onclick="
">IVE (아이브)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4084947?wl_ref=list_tr_11_chart" class="album" title="I've IVE"
onclick="
">I've IVE</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6195812',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6195812');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6195812');
"
track_title="I AM" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6195812','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6195812, 616170, 'Y', 'Y', 'Y', 'Y', 6195812, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6195812','0','4084947','bugs.music.listenRadioFromSeed(\'6195812\',\'track\');','N', 'Y', '_chart');
"
track_title="I AM"
artist_id="20148657"
artist_disp_nm="IVE (아이브)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20744778" artistId="20155724" mvId="0" trackId="33625951" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33625951" />
<input type="hidden" name="_isDown" value="33625951" />
<td class="check"><input type="checkbox" value="33625951" name="check" disc_id="1" title="0+0" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>54</strong>
<p class="change up"><span class="arrow"></span> <em>13</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20744778?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/207447/20744778.jpg?version=20250804122248" onerror="bugs.utils.imgError(this);" alt="자몽살구클럽 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33625951?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33625951',true);
"
title="0+0" aria-label="새창">0+0</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20155724?wl_ref=list_tr_10_chart" title="한로로"
onclick="
">한로로</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20744778?wl_ref=list_tr_11_chart" class="album" title="자몽살구클럽"
onclick="
">자몽살구클럽</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33625951',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33625951');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33625951');
"
track_title="0+0" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33625951','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33625951','0','20744778','bugs.music.listenRadioFromSeed(\'33625951\',\'track\');','N', 'Y', '_chart');
"
track_title="0+0"
artist_id="20155724"
artist_disp_nm="한로로"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4110623" artistId="7570" mvId="0" trackId="6272222" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6272222" />
<input type="hidden" name="_isDown" value="6272222" />
<td class="check"><input type="checkbox" value="6272222" name="check" disc_id="1" title="HOME SWEET HOME (feat. 태양, 대성)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>55</strong>
<p class="change up"><span class="arrow"></span> <em>3</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4110623?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41106/4110623.jpg?version=20241128002601" onerror="bugs.utils.imgError(this);" alt="HOME SWEET HOME (feat. 태양, 대성) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6272222?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6272222',true);
"
title="HOME SWEET HOME (feat. 태양, 대성)" aria-label="새창">HOME SWEET HOME (feat. 태양, 대성)</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/7570?wl_ref=list_tr_10_chart" title="G-DRAGON"
onclick="
">G-DRAGON</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4110623?wl_ref=list_tr_11_chart" class="album" title="HOME SWEET HOME (feat. 태양, 대성)"
onclick="
">HOME SWEET HOME (feat. 태양, 대성)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6272222',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6272222');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6272222');
"
track_title="HOME SWEET HOME (feat. 태양, 대성)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6272222','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6272222','0','4110623','bugs.music.listenRadioFromSeed(\'6272222\',\'track\');','N', 'Y', '_chart');
"
track_title="HOME SWEET HOME (feat. 태양, 대성)"
artist_id="7570"
artist_disp_nm="G-DRAGON"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4112558" artistId="80382214" mvId="629799" trackId="6280186" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6280186" />
<input type="hidden" name="_isDown" value="6280186" />
<td class="check"><input type="checkbox" value="6280186" name="check" disc_id="1" title="오늘만 I LOVE YOU" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>56</strong>
<p class="change down"><span class="arrow"></span> <em>10</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4112558?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41125/4112558.jpg?version=20250108011423" onerror="bugs.utils.imgError(this);" alt="오늘만 I LOVE YOU 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6280186?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6280186',true);
"
title="오늘만 I LOVE YOU" aria-label="새창">오늘만 I LOVE YOU</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80382214?wl_ref=list_tr_10_chart" title="BOYNEXTDOOR"
onclick="
">BOYNEXTDOOR</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4112558?wl_ref=list_tr_11_chart" class="album" title="오늘만 I LOVE YOU"
onclick="
">오늘만 I LOVE YOU</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6280186',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6280186');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6280186');
"
track_title="오늘만 I LOVE YOU" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6280186','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6280186, 629799, 'Y', 'Y', 'Y', 'Y', 6280186, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6280186','0','4112558','bugs.music.listenRadioFromSeed(\'6280186\',\'track\');','N', 'Y', '_chart');
"
track_title="오늘만 I LOVE YOU"
artist_id="80382214"
artist_disp_nm="BOYNEXTDOOR"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20753540" artistId="80245739" mvId="634580" trackId="33665079" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33665079" />
<input type="hidden" name="_isDown" value="33665079" />
<td class="check"><input type="checkbox" value="33665079" name="check" disc_id="1" title="꿈의 버스" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>57</strong>
<p class="change up"><span class="arrow"></span> <em>13</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20753540?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/207535/20753540.jpg?version=20250916011214" onerror="bugs.utils.imgError(this);" alt="The DECADE 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33665079?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33665079',true);
"
title="꿈의 버스" aria-label="새창">꿈의 버스</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20753540?wl_ref=list_tr_11_chart" class="album" title="The DECADE"
onclick="
">The DECADE</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33665079',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33665079');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33665079');
"
track_title="꿈의 버스" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33665079','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33665079, 634580, 'Y', 'Y', 'Y', 'Y', 33665079, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33665079','0','20753540','bugs.music.listenRadioFromSeed(\'33665079\',\'track\');','N', 'Y', '_chart');
"
track_title="꿈의 버스"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4127630" artistId="80049126" mvId="634642" trackId="6344876" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6344876" />
<input type="hidden" name="_isDown" value="6344876" />
<td class="check"><input type="checkbox" value="6344876" name="check" disc_id="1" title="바이, 썸머" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>58</strong>
<p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4127630?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41276/4127630.jpg?version=20250911013055" onerror="bugs.utils.imgError(this);" alt="바이, 썸머 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6344876?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6344876',true);
"
title="바이, 썸머" aria-label="새창">바이, 썸머</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80049126?wl_ref=list_tr_10_chart" title="아이유(IU)"
onclick="
">아이유(IU)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4127630?wl_ref=list_tr_11_chart" class="album" title="바이, 썸머"
onclick="
">바이, 썸머</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6344876',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6344876');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6344876');
"
track_title="바이, 썸머" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6344876','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6344876, 634642, 'Y', 'Y', 'Y', 'Y', 6344876, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6344876','0','4127630','bugs.music.listenRadioFromSeed(\'6344876\',\'track\');','N', 'Y', '_chart');
"
track_title="바이, 썸머"
artist_id="80049126"
artist_disp_nm="아이유(IU)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4116299" artistId="20158908" mvId="631051" trackId="6293885" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6293885" />
<input type="hidden" name="_isDown" value="6293885" />
<td class="check"><input type="checkbox" value="6293885" name="check" disc_id="1" title="HOT" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>59</strong>
<p class="change down"><span class="arrow"></span> <em>7</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4116299?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41162/4116299.jpg?version=20251111013901" onerror="bugs.utils.imgError(this);" alt="HOT 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6293885?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6293885',true);
"
title="HOT" aria-label="새창">HOT</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20158908?wl_ref=list_tr_10_chart" title="LE SSERAFIM (르세라핌)"
onclick="
">LE SSERAFIM (르세라핌)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4116299?wl_ref=list_tr_11_chart" class="album" title="HOT"
onclick="
">HOT</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6293885',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6293885');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6293885');
"
track_title="HOT" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6293885','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6293885, 631051, 'Y', 'Y', 'Y', 'Y', 6293885, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6293885','0','4116299','bugs.music.listenRadioFromSeed(\'6293885\',\'track\');','N', 'Y', '_chart');
"
track_title="HOT"
artist_id="20158908"
artist_disp_nm="LE SSERAFIM (르세라핌)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4078016" artistId="20164333" mvId="610554" trackId="6170217" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6170217" />
<input type="hidden" name="_isDown" value="6170217" />
<td class="check"><input type="checkbox" value="6170217" name="check" disc_id="1" title="Hype Boy" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>60</strong>
<p class="change up"><span class="arrow"></span> <em>32</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40780/4078016.jpg?version=20221014011218" onerror="bugs.utils.imgError(this);" alt="NewJeans 1st EP 'New Jeans' 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6170217?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6170217',true);
"
title="Hype Boy" aria-label="새창">Hype Boy</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" title="NewJeans"
onclick="
">NewJeans</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart" class="album" title="NewJeans 1st EP 'New Jeans'"
onclick="
">NewJeans 1st EP 'New Jeans'</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6170217',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6170217');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6170217');
"
track_title="Hype Boy" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6170217','true','true','44.1','false','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6170217, 610554, 'Y', 'Y', 'Y', 'Y', 6170217, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6170217','0','4078016','bugs.music.listenRadioFromSeed(\'6170217\',\'track\');','N', 'Y', '_chart');
"
track_title="Hype Boy"
artist_id="20164333"
artist_disp_nm="NewJeans"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4094730" artistId="13556684" mvId="622628" trackId="6230613" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6230613" />
<input type="hidden" name="_isDown" value="6230613" />
<td class="check"><input type="checkbox" value="6230613" name="check" disc_id="1" title="첫 만남은 계획대로 되지 않아" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>61</strong>
<p class="change down"><span class="arrow"></span> <em>1</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4094730?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40947/4094730.jpg?version=20250923013257" onerror="bugs.utils.imgError(this);" alt="TWS 1st Mini Album ‘Sparkling Blue’ 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6230613?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6230613',true);
"
title="첫 만남은 계획대로 되지 않아" aria-label="새창">첫 만남은 계획대로 되지 않아</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/13556684?wl_ref=list_tr_10_chart" title="TWS (투어스)"
onclick="
">TWS (투어스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4094730?wl_ref=list_tr_11_chart" class="album" title="TWS 1st Mini Album ‘Sparkling Blue’"
onclick="
">TWS 1st Mini Album ‘Sparkling Blue’</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6230613',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6230613');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6230613');
"
track_title="첫 만남은 계획대로 되지 않아" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6230613','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6230613, 622628, 'Y', 'Y', 'Y', 'Y', 6230613, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6230613','0','4094730','bugs.music.listenRadioFromSeed(\'6230613\',\'track\');','N', 'Y', '_chart');
"
track_title="첫 만남은 계획대로 되지 않아"
artist_id="13556684"
artist_disp_nm="TWS (투어스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="37797179" artistId="80376162" mvId="631904" trackId="124156522" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="124156522" />
<input type="hidden" name="_isDown" value="124156522" />
<td class="check"><input type="checkbox" value="124156522" name="check" disc_id="1" title="Pookie" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>62</strong>
<p class="change up"><span class="arrow"></span> <em>7</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/37797179?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/377971/37797179.jpg?version=20250924011146" onerror="bugs.utils.imgError(this);" alt="Day &amp; Night 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/124156522?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('124156522',true);
"
title="Pookie" aria-label="새창">Pookie</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80376162?wl_ref=list_tr_10_chart" title="FIFTY FIFTY"
onclick="
">FIFTY FIFTY</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/37797179?wl_ref=list_tr_11_chart" class="album" title="Day &amp; Night"
onclick="
">Day &amp; Night</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('124156522',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('124156522');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'124156522');
"
track_title="Pookie" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'124156522','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,124156522, 631904, 'Y', 'Y', 'Y', 'Y', 124156522, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'124156522','0','37797179','bugs.music.listenRadioFromSeed(\'124156522\',\'track\');','N', 'Y', '_chart');
"
track_title="Pookie"
artist_id="80376162"
artist_disp_nm="FIFTY FIFTY"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20080494" artistId="80245739" mvId="313490" trackId="30540153" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="30540153" />
<input type="hidden" name="_isDown" value="30540153" />
<td class="check"><input type="checkbox" value="30540153" name="check" disc_id="1" title="예뻤어" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>63</strong>
<p class="change up"><span class="arrow"></span> <em>10</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20080494?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/200804/20080494.jpg?version=20240805121438" onerror="bugs.utils.imgError(this);" alt="Every DAY6 February 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/30540153?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30540153',true);
"
title="예뻤어" aria-label="새창">예뻤어</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20080494?wl_ref=list_tr_11_chart" class="album" title="Every DAY6 February"
onclick="
">Every DAY6 February</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('30540153',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('30540153');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'30540153');
"
track_title="예뻤어" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'30540153','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,30540153, 313490, 'Y', 'Y', 'Y', 'Y', 30540153, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'30540153','0','20080494','bugs.music.listenRadioFromSeed(\'30540153\',\'track\');','N', 'Y', '_chart');
"
track_title="예뻤어"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4128834" artistId="13556684" mvId="635205" trackId="6360702" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6360702" />
<input type="hidden" name="_isDown" value="6360702" />
<td class="check"><input type="checkbox" value="6360702" name="check" disc_id="1" title="OVERDRIVE" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>64</strong>
<p class="change none"><em>0</em><span>변동없음</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4128834?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41288/4128834.jpg?version=20251014031813" onerror="bugs.utils.imgError(this);" alt="TWS 4th Mini Album ‘play hard’ 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6360702?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6360702',true);
"
title="OVERDRIVE" aria-label="새창">OVERDRIVE</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/13556684?wl_ref=list_tr_10_chart" title="TWS (투어스)"
onclick="
">TWS (투어스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4128834?wl_ref=list_tr_11_chart" class="album" title="TWS 4th Mini Album ‘play hard’"
onclick="
">TWS 4th Mini Album ‘play hard’</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6360702',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6360702');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6360702');
"
track_title="OVERDRIVE" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6360702','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6360702, 635205, 'Y', 'Y', 'Y', 'Y', 6360702, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6360702','0','4128834','bugs.music.listenRadioFromSeed(\'6360702\',\'track\');','N', 'Y', '_chart');
"
track_title="OVERDRIVE"
artist_id="13556684"
artist_disp_nm="TWS (투어스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4082425" artistId="20164333" mvId="613861" trackId="6184997" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6184997" />
<input type="hidden" name="_isDown" value="6184997" />
<td class="check"><input type="checkbox" value="6184997" name="check" disc_id="1" title="Ditto" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>65</strong>
<p class="change down"><span class="arrow"></span> <em>20</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40824/4082425.jpg?version=20231215003716" onerror="bugs.utils.imgError(this);" alt="NewJeans 'OMG' 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6184997?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6184997',true);
"
title="Ditto" aria-label="새창">Ditto</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" title="NewJeans"
onclick="
">NewJeans</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_11_chart" class="album" title="NewJeans 'OMG'"
onclick="
">NewJeans 'OMG'</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6184997',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6184997');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6184997');
"
track_title="Ditto" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6184997','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6184997, 613861, 'Y', 'Y', 'Y', 'Y', 6184997, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6184997','0','4082425','bugs.music.listenRadioFromSeed(\'6184997\',\'track\');','N', 'Y', '_chart');
"
track_title="Ditto"
artist_id="20164333"
artist_disp_nm="NewJeans"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4118481" artistId="80398939" mvId="631969" trackId="6302391" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6302391" />
<input type="hidden" name="_isDown" value="6302391" />
<td class="check"><input type="checkbox" value="6302391" name="check" disc_id="1" title="HANDS UP" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>66</strong>
<p class="change up"><span class="arrow"></span> <em>23</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4118481?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41184/4118481.jpg?version=20250514021619" onerror="bugs.utils.imgError(this);" alt="MY EYES OPEN VVIDE 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6302391?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6302391',true);
"
title="HANDS UP" aria-label="새창">HANDS UP</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80398939?wl_ref=list_tr_10_chart" title="MEOVV (미야오)"
onclick="
">MEOVV (미야오)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4118481?wl_ref=list_tr_11_chart" class="album" title="MY EYES OPEN VVIDE"
onclick="
">MY EYES OPEN VVIDE</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6302391',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6302391');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6302391');
"
track_title="HANDS UP" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6302391','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6302391, 631969, 'Y', 'Y', 'Y', 'Y', 6302391, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6302391','0','4118481','bugs.music.listenRadioFromSeed(\'6302391\',\'track\');','N', 'Y', '_chart');
"
track_title="HANDS UP"
artist_id="80398939"
artist_disp_nm="MEOVV (미야오)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20237198" artistId="80188909" mvId="490610" trackId="31501137" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="31501137" />
<input type="hidden" name="_isDown" value="31501137" />
<td class="check"><input type="checkbox" value="31501137" name="check" disc_id="1" title="주저하는 연인들을 위해" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>67</strong>
<p class="change down"><span class="arrow"></span> <em>14</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20237198?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/202371/20237198.jpg?version=20210421045158" onerror="bugs.utils.imgError(this);" alt="전설 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/31501137?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31501137',true);
"
title="주저하는 연인들을 위해" aria-label="새창">주저하는 연인들을 위해</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80188909?wl_ref=list_tr_10_chart" title="잔나비"
onclick="
">잔나비</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20237198?wl_ref=list_tr_11_chart" class="album" title="전설"
onclick="
">전설</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('31501137',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('31501137');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'31501137');
"
track_title="주저하는 연인들을 위해" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'31501137','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,31501137, 490610, 'Y', 'Y', 'Y', 'Y', 31501137, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'31501137','0','20237198','bugs.music.listenRadioFromSeed(\'31501137\',\'track\');','N', 'Y', '_chart');
"
track_title="주저하는 연인들을 위해"
artist_id="80188909"
artist_disp_nm="잔나비"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4115621" artistId="7570" mvId="630690" trackId="6290922" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6290922" />
<input type="hidden" name="_isDown" value="6290922" />
<td class="check"><input type="checkbox" value="6290922" name="check" disc_id="1" title="TOO BAD (feat. Anderson .Paak)" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>68</strong>
<p class="change up"><span class="arrow"></span> <em>3</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4115621?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41156/4115621.jpg?version=20250910003408" onerror="bugs.utils.imgError(this);" alt="Übermensch 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6290922?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6290922',true);
"
title="TOO BAD (feat. Anderson .Paak)" aria-label="새창">TOO BAD (feat. Anderson .Paak)</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/7570?wl_ref=list_tr_10_chart" title="G-DRAGON"
onclick="
">G-DRAGON</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4115621?wl_ref=list_tr_11_chart" class="album" title="Übermensch"
onclick="
">Übermensch</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6290922',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6290922');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6290922');
"
track_title="TOO BAD (feat. Anderson .Paak)" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6290922','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6290922, 630690, 'Y', 'Y', 'Y', 'Y', 6290922, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6290922','0','4115621','bugs.music.listenRadioFromSeed(\'6290922\',\'track\');','N', 'Y', '_chart');
"
track_title="TOO BAD (feat. Anderson .Paak)"
artist_id="7570"
artist_disp_nm="G-DRAGON"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4115087" artistId="20229752" mvId="630526" trackId="6288426" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6288426" />
<input type="hidden" name="_isDown" value="6288426" />
<td class="check"><input type="checkbox" value="6288426" name="check" disc_id="1" title="I DO ME" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>69</strong>
<p class="change up"><span class="arrow"></span> <em>13</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4115087?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41150/4115087.jpg?version=20250425011550" onerror="bugs.utils.imgError(this);" alt="UNCUT GEM 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6288426?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6288426',true);
"
title="I DO ME" aria-label="새창">I DO ME</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20229752?wl_ref=list_tr_10_chart" title="KiiiKiii (키키)"
onclick="
">KiiiKiii (키키)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4115087?wl_ref=list_tr_11_chart" class="album" title="UNCUT GEM"
onclick="
">UNCUT GEM</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6288426',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6288426');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6288426');
"
track_title="I DO ME" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6288426','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6288426, 630526, 'Y', 'Y', 'Y', 'Y', 6288426, 'N','OVER_12', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6288426','0','4115087','bugs.music.listenRadioFromSeed(\'6288426\',\'track\');','N', 'Y', '_chart');
"
track_title="I DO ME"
artist_id="20229752"
artist_disp_nm="KiiiKiii (키키)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4126265" artistId="80123432" mvId="0" trackId="6340161" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6340161" />
<input type="hidden" name="_isDown" value="6340161" />
<td class="check"><input type="checkbox" value="6340161" name="check" disc_id="1" title="한번 더 이별" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>70</strong>
<p class="change down"><span class="arrow"></span> <em>8</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4126265?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41262/4126265.jpg?version=20250828022008" onerror="bugs.utils.imgError(this);" alt="한번 더 이별 (첫사랑 엔딩 X 이창섭) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6340161?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6340161',true);
"
title="한번 더 이별" aria-label="새창">한번 더 이별</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80123432?wl_ref=list_tr_10_chart" title="이창섭"
onclick="
">이창섭</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4126265?wl_ref=list_tr_11_chart" class="album" title="한번 더 이별 (첫사랑 엔딩 X 이창섭)"
onclick="
">한번 더 이별 (첫사랑 엔딩 X 이창섭)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6340161',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6340161');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6340161');
"
track_title="한번 더 이별" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6340161','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6340161','0','4126265','bugs.music.listenRadioFromSeed(\'6340161\',\'track\');','N', 'Y', '_chart');
"
track_title="한번 더 이별"
artist_id="80123432"
artist_disp_nm="이창섭"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4113098" artistId="20148657" mvId="630294" trackId="6284624" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6284624" />
<input type="hidden" name="_isDown" value="6284624" />
<td class="check"><input type="checkbox" value="6284624" name="check" disc_id="1" title="ATTITUDE" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>71</strong>
<p class="change up"><span class="arrow"></span> <em>8</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4113098?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41130/4113098.jpg?version=20250213010511" onerror="bugs.utils.imgError(this);" alt="IVE EMPATHY 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6284624?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6284624',true);
"
title="ATTITUDE" aria-label="새창">ATTITUDE</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20148657?wl_ref=list_tr_10_chart" title="IVE (아이브)"
onclick="
">IVE (아이브)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4113098?wl_ref=list_tr_11_chart" class="album" title="IVE EMPATHY"
onclick="
">IVE EMPATHY</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6284624',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6284624');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6284624');
"
track_title="ATTITUDE" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6284624','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6284624, 630294, 'Y', 'Y', 'Y', 'Y', 6284624, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6284624','0','4113098','bugs.music.listenRadioFromSeed(\'6284624\',\'track\');','N', 'Y', '_chart');
"
track_title="ATTITUDE"
artist_id="20148657"
artist_disp_nm="IVE (아이브)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4120415" artistId="80049126" mvId="632474" trackId="6310980" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6310980" />
<input type="hidden" name="_isDown" value="6310980" />
<td class="check"><input type="checkbox" value="6310980" name="check" disc_id="1" title="Never Ending Story" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>72</strong>
<p class="change down"><span class="arrow"></span> <em>9</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4120415?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41204/4120415.jpg?version=20250529011654" onerror="bugs.utils.imgError(this);" alt="꽃갈피 셋 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6310980?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6310980',true);
"
title="Never Ending Story" aria-label="새창">Never Ending Story</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80049126?wl_ref=list_tr_10_chart" title="아이유(IU)"
onclick="
">아이유(IU)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4120415?wl_ref=list_tr_11_chart" class="album" title="꽃갈피 셋"
onclick="
">꽃갈피 셋</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6310980',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6310980');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6310980');
"
track_title="Never Ending Story" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6310980','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6310980, 632474, 'Y', 'Y', 'Y', 'Y', 6310980, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6310980','0','4120415','bugs.music.listenRadioFromSeed(\'6310980\',\'track\');','N', 'Y', '_chart');
"
track_title="Never Ending Story"
artist_id="80049126"
artist_disp_nm="아이유(IU)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20323788" artistId="80245739" mvId="0" trackId="31908735" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="31908735" />
<input type="hidden" name="_isDown" value="31908735" />
<td class="check"><input type="checkbox" value="31908735" name="check" disc_id="1" title="Love me or Leave me" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>73</strong>
<p class="change up"><span class="arrow"></span> <em>12</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20323788?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/203237/20323788.jpg?version=20241114011724" onerror="bugs.utils.imgError(this);" alt="The Book of Us : The Demon 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/31908735?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31908735',true);
"
title="Love me or Leave me" aria-label="새창">Love me or Leave me</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20323788?wl_ref=list_tr_11_chart" class="album" title="The Book of Us : The Demon"
onclick="
">The Book of Us : The Demon</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('31908735',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('31908735');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'31908735');
"
track_title="Love me or Leave me" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'31908735','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'31908735','0','20323788','bugs.music.listenRadioFromSeed(\'31908735\',\'track\');','N', 'Y', '_chart');
"
track_title="Love me or Leave me"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4131052" artistId="80382214" mvId="635349" trackId="6363792" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6363792" />
<input type="hidden" name="_isDown" value="6363792" />
<td class="check"><input type="checkbox" value="6363792" name="check" disc_id="1" title="Hollywood Action" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>74</strong>
<p class="change up"><span class="arrow"></span> <em>14</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4131052?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41310/4131052.jpg?version=20251024004042" onerror="bugs.utils.imgError(this);" alt="The Action 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6363792?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6363792',true);
"
title="Hollywood Action" aria-label="새창">Hollywood Action</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80382214?wl_ref=list_tr_10_chart" title="BOYNEXTDOOR"
onclick="
">BOYNEXTDOOR</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4131052?wl_ref=list_tr_11_chart" class="album" title="The Action"
onclick="
">The Action</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6363792',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6363792');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6363792');
"
track_title="Hollywood Action" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6363792','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6363792, 635349, 'Y', 'Y', 'Y', 'Y', 6363792, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6363792','0','4131052','bugs.music.listenRadioFromSeed(\'6363792\',\'track\');','N', 'Y', '_chart');
"
track_title="Hollywood Action"
artist_id="80382214"
artist_disp_nm="BOYNEXTDOOR"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20753540" artistId="80245739" mvId="634543" trackId="33665080" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33665080" />
<input type="hidden" name="_isDown" value="33665080" />
<td class="check"><input type="checkbox" value="33665080" name="check" disc_id="1" title="INSIDE OUT" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>75</strong>
<p class="change up"><span class="arrow"></span> <em>1</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20753540?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/207535/20753540.jpg?version=20250916011214" onerror="bugs.utils.imgError(this);" alt="The DECADE 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33665080?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33665080',true);
"
title="INSIDE OUT" aria-label="새창">INSIDE OUT</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20753540?wl_ref=list_tr_11_chart" class="album" title="The DECADE"
onclick="
">The DECADE</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33665080',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33665080');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33665080');
"
track_title="INSIDE OUT" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33665080','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33665080, 634543, 'Y', 'Y', 'Y', 'Y', 33665080, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33665080','0','20753540','bugs.music.listenRadioFromSeed(\'33665080\',\'track\');','N', 'Y', '_chart');
"
track_title="INSIDE OUT"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4132770" artistId="80203317" mvId="0" trackId="6373880" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="6373880" />
<input type="hidden" name="_isDown" value="6373880" />
<td class="check"><input type="checkbox" value="6373880" name="check" disc_id="1" title="나였으면" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>76</strong>
<p class="change down"><span class="arrow"></span> <em>2</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4132770?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41327/4132770.jpg?version=20251108020106" onerror="bugs.utils.imgError(this);" alt="나였으면 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6373880?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6373880',true);
"
title="나였으면" aria-label="새창">나였으면</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/72394?wl_ref=list_tr_10_chart" class="artistTitle" title="나윤권" >나윤권</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, '나윤권||나윤권||72394||OK\\n도경수||도경수(D.O.)||80203317||OK', ''); return false;">
나윤권
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4132770?wl_ref=list_tr_11_chart" class="album" title="나였으면"
onclick="
">나였으면</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6373880',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6373880');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6373880');
"
track_title="나였으면" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6373880','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6373880','0','4132770','bugs.music.listenRadioFromSeed(\'6373880\',\'track\');','N', 'Y', '_chart');
"
track_title="나였으면"
artist_id="80203317"
artist_disp_nm="도경수(D.O.)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4121085" artistId="80347326" mvId="633042" trackId="6314885" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6314885" />
<input type="hidden" name="_isDown" value="6314885" />
<td class="check"><input type="checkbox" value="6314885" name="check" disc_id="1" title="Dirty Work" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>77</strong>
<p class="change down"><span class="arrow"></span> <em>12</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4121085?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41210/4121085.jpg?version=20250628011258" onerror="bugs.utils.imgError(this);" alt="Dirty Work 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6314885?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6314885',true);
"
title="Dirty Work" aria-label="새창">Dirty Work</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80347326?wl_ref=list_tr_10_chart" title="aespa"
onclick="
">aespa</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4121085?wl_ref=list_tr_11_chart" class="album" title="Dirty Work"
onclick="
">Dirty Work</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6314885',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6314885');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6314885');
"
track_title="Dirty Work" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6314885','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6314885, 633042, 'Y', 'Y', 'Y', 'Y', 6314885, 'N','OVER_15', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6314885','0','4121085','bugs.music.listenRadioFromSeed(\'6314885\',\'track\');','N', 'Y', '_chart');
"
track_title="Dirty Work"
artist_id="80347326"
artist_disp_nm="aespa"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4112411" artistId="80109484" mvId="0" trackId="6279501" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6279501" />
<input type="hidden" name="_isDown" value="6279501" />
<td class="check"><input type="checkbox" value="6279501" name="check" disc_id="1" title="시작의 아이" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>78</strong>
<p class="change down"><span class="arrow"></span> <em>37</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4112411?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41124/4112411.jpg?version=20250618004611" onerror="bugs.utils.imgError(this);" alt="시작의 아이 ハジマリのコ (Starting With You) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6279501?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6279501',true);
"
title="시작의 아이" aria-label="새창">시작의 아이</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80109484?wl_ref=list_tr_10_chart" title="마크툽(MAKTUB)"
onclick="
">마크툽(MAKTUB)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4112411?wl_ref=list_tr_11_chart" class="album" title="시작의 아이 ハジマリのコ (Starting With You)"
onclick="
">시작의 아이 ハジマリのコ (Starting With You)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6279501',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6279501');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6279501');
"
track_title="시작의 아이" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6279501','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6279501','0','4112411','bugs.music.listenRadioFromSeed(\'6279501\',\'track\');','N', 'Y', '_chart');
"
track_title="시작의 아이"
artist_id="80109484"
artist_disp_nm="마크툽(MAKTUB)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="680332" artistId="80010088" mvId="579652" trackId="5035960" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="5035960" />
<input type="hidden" name="_isDown" value="5035960" />
<td class="check"><input type="checkbox" value="5035960" name="check" disc_id="1" title="Snowman" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>79</strong>
<p class="change up"><span class="arrow"></span> <em>14</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/680332?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/6803/680332.jpg?version=20251108020318" onerror="bugs.utils.imgError(this);" alt="Everyday Is Christmas (Snowman Deluxe Edition) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/5035960?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('5035960',true);
"
title="Snowman" aria-label="새창">Snowman</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80010088?wl_ref=list_tr_10_chart" title="Sia(시아)"
onclick="
">Sia(시아)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/680332?wl_ref=list_tr_11_chart" class="album" title="Everyday Is Christmas (Snowman Deluxe Edition)"
onclick="
">Everyday Is Christmas (Snowman Deluxe Edition)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('5035960',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('5035960');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'5035960');
"
track_title="Snowman" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'5035960','true','true','44.1','false','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,5035960, 579652, 'Y', 'Y', 'Y', 'Y', 5035960, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'5035960','0','680332','bugs.music.listenRadioFromSeed(\'5035960\',\'track\');','N', 'Y', '_chart');
"
track_title="Snowman"
artist_id="80010088"
artist_disp_nm="Sia(시아)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="38176338" artistId="80408375" mvId="0" trackId="125523554" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="125523554" />
<input type="hidden" name="_isDown" value="125523554" />
<td class="check"><input type="checkbox" value="125523554" name="check" disc_id="1" title="Takedown" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>80</strong>
<p class="change up"><span class="arrow"></span> <em>7</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/381763/38176338.jpg?version=20250927005933" onerror="bugs.utils.imgError(this);" alt="KPop Demon Hunters (Soundtrack from the Netflix Film) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/125523554?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('125523554',true);
"
title="Takedown" aria-label="새창">Takedown</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/80408375?wl_ref=list_tr_10_chart" class="artistTitle" title="HUNTR/X" >HUNTR/X</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'HUNTR/X||HUNTR/X||80408375||OK\\nEJAE||EJAE||20021140||OK\\nAUDREY NUNA||AUDREY NUNA||80332178||OK\\nREI AMI||REI AMI||20089314||OK\\nKPop Demon Hunters Cast||KPop Demon Hunters Cast||14262785||OK', ''); return false;">
HUNTR/X
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_11_chart" class="album" title="KPop Demon Hunters (Soundtrack from the Netflix Film)"
onclick="
">KPop Demon Hunters (Soundtrack from the Netflix Film)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('125523554',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('125523554');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'125523554');
"
track_title="Takedown" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'125523554','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'125523554','0','38176338','bugs.music.listenRadioFromSeed(\'125523554\',\'track\');','N', 'Y', '_chart');
"
track_title="Takedown"
artist_id="80408375"
artist_disp_nm="HUNTR/X"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4121045" artistId="13456593" mvId="632668" trackId="6314533" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6314533" />
<input type="hidden" name="_isDown" value="6314533" />
<td class="check"><input type="checkbox" value="6314533" name="check" disc_id="1" title="눈물참기" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>81</strong>
<p class="change down"><span class="arrow"></span> <em>13</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4121045?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41210/4121045.jpg?version=20250611010118" onerror="bugs.utils.imgError(this);" alt="3rd Mini Album '난 네 편이야, 온 세상이 불협일지라도' 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6314533?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6314533',true);
"
title="눈물참기" aria-label="새창">눈물참기</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/13456593?wl_ref=list_tr_10_chart" title="QWER"
onclick="
">QWER</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4121045?wl_ref=list_tr_11_chart" class="album" title="3rd Mini Album '난 네 편이야, 온 세상이 불협일지라도'"
onclick="
">3rd Mini Album '난 네 편이야, 온 세상이 불협일지라도'</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6314533',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6314533');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6314533');
"
track_title="눈물참기" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6314533','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6314533, 632668, 'Y', 'Y', 'Y', 'Y', 6314533, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6314533','0','4121045','bugs.music.listenRadioFromSeed(\'6314533\',\'track\');','N', 'Y', '_chart');
"
track_title="눈물참기"
artist_id="13456593"
artist_disp_nm="QWER"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4095394" artistId="20056456" mvId="0" trackId="6230392" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6230392" />
<input type="hidden" name="_isDown" value="6230392" />
<td class="check"><input type="checkbox" value="6230392" name="check" disc_id="1" title="나는 아픈 건 딱 질색이니까" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>82</strong>
<p class="change down"><span class="arrow"></span> <em>10</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4095394?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40953/4095394.jpg?version=20250503021216" onerror="bugs.utils.imgError(this);" alt="2 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6230392?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6230392',true);
"
title="나는 아픈 건 딱 질색이니까" aria-label="새창">나는 아픈 건 딱 질색이니까</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20056456?wl_ref=list_tr_10_chart" title="i-dle (아이들)"
onclick="
">i-dle (아이들)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4095394?wl_ref=list_tr_11_chart" class="album" title="2"
onclick="
">2</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6230392',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6230392');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6230392');
"
track_title="나는 아픈 건 딱 질색이니까" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6230392','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6230392','0','4095394','bugs.music.listenRadioFromSeed(\'6230392\',\'track\');','N', 'Y', '_chart');
"
track_title="나는 아픈 건 딱 질색이니까"
artist_id="20056456"
artist_disp_nm="i-dle (아이들)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="38176338" artistId="80147633" mvId="0" trackId="125523556" multiArtist="Y" rowType="track" >
<input type="hidden" name="_isStream" value="125523556" />
<input type="hidden" name="_isDown" value="125523556" />
<td class="check"><input type="checkbox" value="125523556" name="check" disc_id="1" title="Free" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>83</strong>
<p class="change up"><span class="arrow"></span> <em>29</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/381763/38176338.jpg?version=20250927005933" onerror="bugs.utils.imgError(this);" alt="KPop Demon Hunters (Soundtrack from the Netflix Film) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/125523556?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('125523556',true);
"
title="Free" aria-label="새창">Free</a>
</p>
</th>
<td class="left">
<p class="artist">
<!-- a tag title -->
<a href="https://music.bugs.co.kr/artist/80408447?wl_ref=list_tr_10_chart" class="artistTitle" title="Rumi" >Rumi</a>
<!-- a tag link -->
<a href="javascript:void(0);" name="atag_martist_list" class="more" title="아티스트 전체보기" wise_log_str="?wl_ref=list_tr_10_chart" onclick="bugs.layermenu.openMultiArtistSearchResultPopLayer(this, 'Rumi||Rumi||80408447||OK\\nJinu||Jinu||14262807||OK\\nEJAE||EJAE||20021140||OK\\nAndrew Choi||Andrew Choi||80147633||OK\\nKPop Demon Hunters Cast||KPop Demon Hunters Cast||14262785||OK', ''); return false;">
Rumi
</a> </p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/38176338?wl_ref=list_tr_11_chart" class="album" title="KPop Demon Hunters (Soundtrack from the Netflix Film)"
onclick="
">KPop Demon Hunters (Soundtrack from the Netflix Film)</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('125523556',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('125523556');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'125523556');
"
track_title="Free" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'125523556','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'125523556','0','38176338','bugs.music.listenRadioFromSeed(\'125523556\',\'track\');','N', 'Y', '_chart');
"
track_title="Free"
artist_id="80147633"
artist_disp_nm="Andrew Choi"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4108354" artistId="80265678" mvId="628148" trackId="6265434" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6265434" />
<input type="hidden" name="_isDown" value="6265434" />
<td class="check"><input type="checkbox" value="6265434" name="check" disc_id="1" title="Mantra" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>84</strong>
<p class="change up"><span class="arrow"></span> <em>10</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4108354?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41083/4108354.jpg?version=20241017004618" onerror="bugs.utils.imgError(this);" alt="Mantra 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6265434?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6265434',true);
"
title="Mantra" aria-label="새창">Mantra</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80265678?wl_ref=list_tr_10_chart" title="제니 (JENNIE)"
onclick="
">제니 (JENNIE)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4108354?wl_ref=list_tr_11_chart" class="album" title="Mantra"
onclick="
">Mantra</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6265434',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6265434');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6265434');
"
track_title="Mantra" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6265434','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6265434, 628148, 'Y', 'Y', 'Y', 'Y', 6265434, 'N','OVER_15', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6265434','0','4108354','bugs.music.listenRadioFromSeed(\'6265434\',\'track\');','N', 'Y', '_chart');
"
track_title="Mantra"
artist_id="80265678"
artist_disp_nm="제니 (JENNIE)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20771333" artistId="20046081" mvId="636126" trackId="33751683" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33751683" />
<input type="hidden" name="_isDown" value="33751683" />
<td class="check"><input type="checkbox" value="33751683" name="check" disc_id="1" title="Do It" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>85</strong>
<p class="change up"><span class="arrow"></span> <em>15</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20771333?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/207713/20771333.jpg?version=20251129020329" onerror="bugs.utils.imgError(this);" alt="DO IT 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33751683?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33751683',true);
"
title="Do It" aria-label="새창">Do It</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20046081?wl_ref=list_tr_10_chart" title="Stray Kids (스트레이 키즈)"
onclick="
">Stray Kids (스트레이 키즈)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20771333?wl_ref=list_tr_11_chart" class="album" title="DO IT"
onclick="
">DO IT</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33751683',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33751683');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33751683');
"
track_title="Do It" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33751683','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33751683, 636126, 'Y', 'Y', 'Y', 'Y', 33751683, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33751683','0','20771333','bugs.music.listenRadioFromSeed(\'33751683\',\'track\');','N', 'Y', '_chart');
"
track_title="Do It"
artist_id="20046081"
artist_disp_nm="Stray Kids (스트레이 키즈)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4130461" artistId="80398939" mvId="635234" trackId="6360947" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6360947" />
<input type="hidden" name="_isDown" value="6360947" />
<td class="check"><input type="checkbox" value="6360947" name="check" disc_id="1" title="BURNING UP" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>86</strong>
<p class="change up"><span class="arrow"></span> <em>13</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4130461?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41304/4130461.jpg?version=20251104010750" onerror="bugs.utils.imgError(this);" alt="BURNING UP 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6360947?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6360947',true);
"
title="BURNING UP" aria-label="새창">BURNING UP</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80398939?wl_ref=list_tr_10_chart" title="MEOVV (미야오)"
onclick="
">MEOVV (미야오)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4130461?wl_ref=list_tr_11_chart" class="album" title="BURNING UP"
onclick="
">BURNING UP</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6360947',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6360947');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6360947');
"
track_title="BURNING UP" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6360947','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6360947, 635234, 'Y', 'Y', 'Y', 'Y', 6360947, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6360947','0','4130461','bugs.music.listenRadioFromSeed(\'6360947\',\'track\');','N', 'Y', '_chart');
"
track_title="BURNING UP"
artist_id="80398939"
artist_disp_nm="MEOVV (미야오)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4090168" artistId="20063172" mvId="0" trackId="6212711" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6212711" />
<input type="hidden" name="_isDown" value="6212711" />
<td class="check"><input type="checkbox" value="6212711" name="check" disc_id="1" title="그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>87</strong>
<p class="change down"><span class="arrow"></span> <em>12</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4090168?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40901/4090168.jpg?version=20240209005514" onerror="bugs.utils.imgError(this);" alt="그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6212711?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6212711',true);
"
title="그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))" aria-label="새창">그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20063172?wl_ref=list_tr_10_chart" title="너드커넥션(Nerd Connection)"
onclick="
">너드커넥션(Nerd Connection)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4090168?wl_ref=list_tr_11_chart" class="album" title="그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))"
onclick="
">그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6212711',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6212711');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6212711');
"
track_title="그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6212711','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6212711','0','4090168','bugs.music.listenRadioFromSeed(\'6212711\',\'track\');','N', 'Y', '_chart');
"
track_title="그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))"
artist_id="20063172"
artist_disp_nm="너드커넥션(Nerd Connection)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="529710" artistId="80245739" mvId="226911" trackId="4551006" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="4551006" />
<input type="hidden" name="_isDown" value="4551006" />
<td class="check"><input type="checkbox" value="4551006" name="check" disc_id="1" title="Congratulations" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>88</strong>
<p class="change up"><span class="arrow"></span> <em>8</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/529710?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/5297/529710.jpg?version=20190719114948" onerror="bugs.utils.imgError(this);" alt="The Day 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/4551006?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('4551006',true);
"
title="Congratulations" aria-label="새창">Congratulations</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/529710?wl_ref=list_tr_11_chart" class="album" title="The Day"
onclick="
">The Day</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('4551006',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('4551006');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'4551006');
"
track_title="Congratulations" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'4551006','true','true','44.1','false','', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,4551006, 226911, 'Y', 'Y', 'Y', 'Y', 4551006, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'4551006','0','529710','bugs.music.listenRadioFromSeed(\'4551006\',\'track\');','N', 'Y', '_chart');
"
track_title="Congratulations"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4106548" artistId="13456593" mvId="627646" trackId="6262712" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6262712" />
<input type="hidden" name="_isDown" value="6262712" />
<td class="check"><input type="checkbox" value="6262712" name="check" disc_id="1" title="내 이름 맑음" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>89</strong>
<p class="change down"><span class="arrow"></span> <em>3</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4106548?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41065/4106548.jpg?version=20250107004107" onerror="bugs.utils.imgError(this);" alt="2nd Mini Album 'Algorithm's Blossom' 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6262712?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6262712',true);
"
title="내 이름 맑음" aria-label="새창">내 이름 맑음</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/13456593?wl_ref=list_tr_10_chart" title="QWER"
onclick="
">QWER</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4106548?wl_ref=list_tr_11_chart" class="album" title="2nd Mini Album 'Algorithm's Blossom'"
onclick="
">2nd Mini Album 'Algorithm's Blossom'</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6262712',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6262712');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6262712');
"
track_title="내 이름 맑음" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6262712','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6262712, 627646, 'Y', 'Y', 'Y', 'Y', 6262712, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6262712','0','4106548','bugs.music.listenRadioFromSeed(\'6262712\',\'track\');','N', 'Y', '_chart');
"
track_title="내 이름 맑음"
artist_id="13456593"
artist_disp_nm="QWER"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4134139" artistId="80384286" mvId="636222" trackId="6380418" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6380418" />
<input type="hidden" name="_isDown" value="6380418" />
<td class="check"><input type="checkbox" value="6380418" name="check" disc_id="1" title="Fame" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>90</strong>
<p class="change down"><span class="arrow"></span> <em>12</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4134139?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41341/4134139.jpg?version=20251203012535" onerror="bugs.utils.imgError(this);" alt="Fame 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6380418?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6380418',true);
"
title="Fame" aria-label="새창">Fame</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80384286?wl_ref=list_tr_10_chart" title="RIIZE"
onclick="
">RIIZE</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4134139?wl_ref=list_tr_11_chart" class="album" title="Fame"
onclick="
">Fame</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6380418',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6380418');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6380418');
"
track_title="Fame" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6380418','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6380418, 636222, 'Y', 'Y', 'Y', 'Y', 6380418, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6380418','0','4134139','bugs.music.listenRadioFromSeed(\'6380418\',\'track\');','N', 'Y', '_chart');
"
track_title="Fame"
artist_id="80384286"
artist_disp_nm="RIIZE"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4102781" artistId="20164333" mvId="625889" trackId="6249329" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6249329" />
<input type="hidden" name="_isDown" value="6249329" />
<td class="check"><input type="checkbox" value="6249329" name="check" disc_id="1" title="Supernatural" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>91</strong>
<p class="change down"><span class="arrow"></span> <em>7</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4102781?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41027/4102781.jpg?version=20250207012050" onerror="bugs.utils.imgError(this);" alt="Supernatural 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6249329?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6249329',true);
"
title="Supernatural" aria-label="새창">Supernatural</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" title="NewJeans"
onclick="
">NewJeans</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4102781?wl_ref=list_tr_11_chart" class="album" title="Supernatural"
onclick="
">Supernatural</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6249329',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6249329');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6249329');
"
track_title="Supernatural" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6249329','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6249329, 625889, 'Y', 'Y', 'Y', 'Y', 6249329, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6249329','0','4102781','bugs.music.listenRadioFromSeed(\'6249329\',\'track\');','N', 'Y', '_chart');
"
track_title="Supernatural"
artist_id="20164333"
artist_disp_nm="NewJeans"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4130248" artistId="20200163" mvId="635174" trackId="6359745" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6359745" />
<input type="hidden" name="_isDown" value="6359745" />
<td class="check"><input type="checkbox" value="6359745" name="check" disc_id="1" title="WE GO UP" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>92</strong>
<p class="change up"><span class="arrow"></span> <em>6</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4130248?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41302/4130248.jpg?version=20251120013900" onerror="bugs.utils.imgError(this);" alt="WE GO UP 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6359745?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6359745',true);
"
title="WE GO UP" aria-label="새창">WE GO UP</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20200163?wl_ref=list_tr_10_chart" title="BABYMONSTER"
onclick="
">BABYMONSTER</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4130248?wl_ref=list_tr_11_chart" class="album" title="WE GO UP"
onclick="
">WE GO UP</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6359745',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6359745');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6359745');
"
track_title="WE GO UP" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6359745','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6359745, 635174, 'Y', 'Y', 'Y', 'Y', 6359745, 'N','OVER_15', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6359745','0','4130248','bugs.music.listenRadioFromSeed(\'6359745\',\'track\');','N', 'Y', '_chart');
"
track_title="WE GO UP"
artist_id="20200163"
artist_disp_nm="BABYMONSTER"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="922832" artistId="80039092" mvId="0" trackId="5725903" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="5725903" />
<input type="hidden" name="_isDown" value="5725903" />
<td class="check"><input type="checkbox" value="5725903" name="check" disc_id="1" title="Cruel Summer" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>93</strong>
<p class="change down"><span class="arrow"></span> <em>3</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/922832?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/9228/922832.jpg?version=20250307141321" onerror="bugs.utils.imgError(this);" alt="Lover 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/5725903?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('5725903',true);
"
title="Cruel Summer" aria-label="새창">Cruel Summer</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80039092?wl_ref=list_tr_10_chart" title="Taylor Swift(테일러 스위프트)"
onclick="
">Taylor Swift(테일러 스위프트)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/922832?wl_ref=list_tr_11_chart" class="album" title="Lover"
onclick="
">Lover</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('5725903',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('5725903');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'5725903');
"
track_title="Cruel Summer" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'5725903','true','true','44.1','true','44.1', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'5725903','0','922832','bugs.music.listenRadioFromSeed(\'5725903\',\'track\');','N', 'Y', '_chart');
"
track_title="Cruel Summer"
artist_id="80039092"
artist_disp_nm="Taylor Swift(테일러 스위프트)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20724195" artistId="80245739" mvId="632091" trackId="33526777" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33526777" />
<input type="hidden" name="_isDown" value="33526777" />
<td class="check"><input type="checkbox" value="33526777" name="check" disc_id="1" title="Maybe Tomorrow" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>94</strong>
<p class="change up"><span class="arrow"></span> <em>3</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20724195?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/207241/20724195.jpg?version=20250508024718" onerror="bugs.utils.imgError(this);" alt="Maybe Tomorrow 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33526777?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33526777',true);
"
title="Maybe Tomorrow" aria-label="새창">Maybe Tomorrow</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80245739?wl_ref=list_tr_10_chart" title="DAY6 (데이식스)"
onclick="
">DAY6 (데이식스)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20724195?wl_ref=list_tr_11_chart" class="album" title="Maybe Tomorrow"
onclick="
">Maybe Tomorrow</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33526777',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33526777');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33526777');
"
track_title="Maybe Tomorrow" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33526777','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33526777, 632091, 'Y', 'Y', 'Y', 'Y', 33526777, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33526777','0','20724195','bugs.music.listenRadioFromSeed(\'33526777\',\'track\');','N', 'Y', '_chart');
"
track_title="Maybe Tomorrow"
artist_id="80245739"
artist_disp_nm="DAY6 (데이식스)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="20635260" artistId="20209337" mvId="626546" trackId="33144670" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="33144670" />
<input type="hidden" name="_isDown" value="33144670" />
<td class="check"><input type="checkbox" value="33144670" name="check" disc_id="1" title="소나기" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>95</strong>
<p class="change down"><span class="arrow"></span> <em>18</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/20635260?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/206352/20635260.jpg?version=20251125080244" onerror="bugs.utils.imgError(this);" alt="선재 업고 튀어 OST Part 1 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/33144670?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33144670',true);
"
title="소나기" aria-label="새창">소나기</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20209337?wl_ref=list_tr_10_chart" title="이클립스 (ECLIPSE)"
onclick="
">이클립스 (ECLIPSE)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/20635260?wl_ref=list_tr_11_chart" class="album" title="선재 업고 튀어 OST Part 1"
onclick="
">선재 업고 튀어 OST Part 1</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('33144670',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('33144670');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'33144670');
"
track_title="소나기" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'33144670','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,33144670, 626546, 'Y', 'Y', 'Y', 'Y', 33144670, 'N','OVER_15', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'33144670','0','20635260','bugs.music.listenRadioFromSeed(\'33144670\',\'track\');','N', 'Y', '_chart');
"
track_title="소나기"
artist_id="20209337"
artist_disp_nm="이클립스 (ECLIPSE)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4095501" artistId="80049126" mvId="622659" trackId="6230788" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6230788" />
<input type="hidden" name="_isDown" value="6230788" />
<td class="check"><input type="checkbox" value="6230788" name="check" disc_id="1" title="Love wins all" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>96</strong>
<p class="change down"><span class="arrow"></span> <em>15</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4095501?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40955/4095501.jpg?version=20250326042636" onerror="bugs.utils.imgError(this);" alt="The Winning 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6230788?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6230788',true);
"
title="Love wins all" aria-label="새창">Love wins all</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80049126?wl_ref=list_tr_10_chart" title="아이유(IU)"
onclick="
">아이유(IU)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4095501?wl_ref=list_tr_11_chart" class="album" title="The Winning"
onclick="
">The Winning</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6230788',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6230788');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6230788');
"
track_title="Love wins all" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6230788','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6230788, 622659, 'Y', 'Y', 'Y', 'Y', 6230788, 'N','ALL', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6230788','0','4095501','bugs.music.listenRadioFromSeed(\'6230788\',\'track\');','N', 'Y', '_chart');
"
track_title="Love wins all"
artist_id="80049126"
artist_disp_nm="아이유(IU)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4116029" artistId="20006511" mvId="631034" trackId="6293526" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6293526" />
<input type="hidden" name="_isDown" value="6293526" />
<td class="check"><input type="checkbox" value="6293526" name="check" disc_id="1" title="Flower" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>97</strong>
<p class="change down"><span class="arrow"></span> <em>43</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4116029?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41160/4116029.jpg?version=20250315024908" onerror="bugs.utils.imgError(this);" alt="교회오빠 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6293526?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6293526',true);
"
title="Flower" aria-label="새창">Flower</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20006511?wl_ref=list_tr_10_chart" title="오반(OVAN)"
onclick="
">오반(OVAN)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4116029?wl_ref=list_tr_11_chart" class="album" title="교회오빠"
onclick="
">교회오빠</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6293526',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6293526');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6293526');
"
track_title="Flower" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6293526','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6293526, 631034, 'Y', 'Y', 'Y', 'Y', 6293526, 'N','ALL', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6293526','0','4116029','bugs.music.listenRadioFromSeed(\'6293526\',\'track\');','N', 'Y', '_chart');
"
track_title="Flower"
artist_id="20006511"
artist_disp_nm="오반(OVAN)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4120415" artistId="80049126" mvId="0" trackId="6310984" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6310984" />
<input type="hidden" name="_isDown" value="6310984" />
<td class="check"><input type="checkbox" value="6310984" name="check" disc_id="1" title="네모의 꿈" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>98</strong>
<p class="change up"><span class="arrow"></span> <em>3</em> <span>계단 상승</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4120415?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41204/4120415.jpg?version=20250529011654" onerror="bugs.utils.imgError(this);" alt="꽃갈피 셋 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6310984?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6310984',true);
"
title="네모의 꿈" aria-label="새창">네모의 꿈</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/80049126?wl_ref=list_tr_10_chart" title="아이유(IU)"
onclick="
">아이유(IU)</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4120415?wl_ref=list_tr_11_chart" class="album" title="꽃갈피 셋"
onclick="
">꽃갈피 셋</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6310984',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6310984');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6310984');
"
track_title="네모의 꿈" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6310984','true','true','44.1','true','96', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<span class="btn viewMV">영상 재생 불가</span>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6310984','0','4120415','bugs.music.listenRadioFromSeed(\'6310984\',\'track\');','N', 'Y', '_chart');
"
track_title="네모의 꿈"
artist_id="80049126"
artist_disp_nm="아이유(IU)"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4109194" artistId="20200163" mvId="628466" trackId="6268450" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6268450" />
<input type="hidden" name="_isDown" value="6268450" />
<td class="check"><input type="checkbox" value="6268450" name="check" disc_id="1" title="DRIP" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>99</strong>
<p class="change down"><span class="arrow"></span> <em>19</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4109194?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/41091/4109194.jpg?version=20250118015053" onerror="bugs.utils.imgError(this);" alt="DRIP 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6268450?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6268450',true);
"
title="DRIP" aria-label="새창">DRIP</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20200163?wl_ref=list_tr_10_chart" title="BABYMONSTER"
onclick="
">BABYMONSTER</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4109194?wl_ref=list_tr_11_chart" class="album" title="DRIP"
onclick="
">DRIP</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6268450',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6268450');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6268450');
"
track_title="DRIP" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6268450','true','true','44.1','true','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6268450, 628466, 'Y', 'Y', 'Y', 'Y', 6268450, 'N','OVER_12', 'N', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6268450','0','4109194','bugs.music.listenRadioFromSeed(\'6268450\',\'track\');','N', 'Y', '_chart');
"
track_title="DRIP"
artist_id="20200163"
artist_disp_nm="BABYMONSTER"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
<tr albumId="4078016" artistId="20164333" mvId="610028" trackId="6170060" multiArtist="N" rowType="track" >
<input type="hidden" name="_isStream" value="6170060" />
<input type="hidden" name="_isDown" value="6170060" />
<td class="check"><input type="checkbox" value="6170060" name="check" disc_id="1" title="Attention" buyMinQuality="T"></td>
<td>
<div class="ranking">
<strong>100</strong>
<p class="change down"><span class="arrow"></span> <em>5</em> <span>계단 하락</span></p>
</div>
</td>
<td>
<a href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_07_chart" class="thumbnail"
onclick="
">
<span class="mask"></span>
<img src="https://image.bugsm.co.kr/album/images/50/40780/4078016.jpg?version=20221014011218" onerror="bugs.utils.imgError(this);" alt="NewJeans 1st EP 'New Jeans' 대표이미지">
</a>
</td>
<td >
<a href="https://music.bugs.co.kr/track/6170060?wl_ref=list_tr_08_chart" class="trackInfo"
onclick="
">곡정보</a>
</td>
<th scope="row">
<p class="title" adult_yn="N">
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6170060',true);
"
title="Attention" aria-label="새창">Attention</a>
</p>
</th>
<td class="left">
<p class="artist">
<a href="https://music.bugs.co.kr/artist/20164333?wl_ref=list_tr_10_chart" title="NewJeans"
onclick="
">NewJeans</a>
</p>
</td>
<td class="left" >
<a href="https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart" class="album" title="NewJeans 1st EP 'New Jeans'"
onclick="
">NewJeans 1st EP 'New Jeans'</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6170060',true);
"
class="btn play" aria-label="새창">듣기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1"
onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6170060');
"
class="btn addPlaylist" aria-label="새창">재생목록에 추가</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6170060');
"
track_title="Attention" class="btn addAlbum">내 앨범에 담기</a>
</td>
<td>
<a href="javascript:;" adultCheckVal="1" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6170060','true','true','44.1','false','48', null );
"
class="btn download flac" aria-label="새창"><em class="flac">flac </em>다운로드</a>
</td>
<td>
<a href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
bugs.layermenu.mv(this,6170060, 610028, 'Y', 'Y', 'Y', 'Y', 6170060, 'N','OVER_12', 'Y', '');
"
class="btn viewMV" aria-label="새창">영상 재생</a>
</td>
<td>
<a href="javascript:;"
onclick="bugs.wiselog.area('list_tr_17_chart');
bugs.layermenu.trackMoreAction(this,'6170060','0','4078016','bugs.music.listenRadioFromSeed(\'6170060\',\'track\');','N', 'Y', '_chart');
"
track_title="Attention"
artist_id="20164333"
artist_disp_nm="NewJeans"
layerPositionTarget="td"
layer_type="CHART"
class="btnActions">기타 기능</a>
</td>
</tr>
</tbody>
</tbody>
</table>
</div>
<div class="pageAdditionalInfo">
<ul>
<li><span class="icon"></span>집계기간 내 듣기와 다운로드 수 합산하여 반영</li>
</ul>
</div>
<script>
$(document).ready(function(){
var contentsBanner = '[]';

if(contentsBanner != "" && contentsBanner != "[]" ){
contentsBanner = bugs.utils.parseJson(contentsBanner);
var wiselogStr = "";
for(var i = 0; i < contentsBanner.length && i < 3; i++){
if(i==0){
wiselogStr = "bugs.wiselog.area('S_sp_04_01');"
}else if( i==1){
wiselogStr = "bugs.wiselog.area('S_sp_04_02');"
}else if( i==2){
wiselogStr = "bugs.wiselog.area('S_sp_04_03');"
}
$('#contentsBanner'+(i+1)).empty();
$('#contentsBanner'+(i+1)).append('<a href="'+contentsBanner[i].link+'" target="'+contentsBanner[i].target+
'" onclick="'+wiselogStr+'bugs.logging.banner('+contentsBanner[i].banner_id+','+"'banner'"+')" title="'+contentsBanner[i].title+'-페이지 이동">'+
'<img src="'+contentsBanner[i].image_path+'" alt="'+contentsBanner[i].title+'"></a>');
}
var oldWidth = $(window).width();
if(oldWidth < 1903){
$('#contentsBanner2').addClass('lineBreak');
}else{
$('#contentsBanner3').addClass('lineBreak');
}
var currentWidth = 0;
$(window).on('resize',function(){
currentWidth = $(window).width();
if(oldWidth < 1903 && 1903 <= currentWidth){
$('#contentsBanner2').removeClass('lineBreak');
$('#contentsBanner3').addClass('lineBreak');
}else if(currentWidth < 1903 && 1903 <= oldWidth){
$('#contentsBanner3').removeClass('lineBreak');
$('#contentsBanner2').addClass('lineBreak');
}
oldWidth = currentWidth;
});
$('aside.contentsBanner').show();
}
});
</script>

<aside class="contentsBanner" style="display:none;">
<ul class="listContentsBanner">
<li id="contentsBanner1">
</li>
<li id="contentsBanner2">
</li>
<li id="contentsBanner3">
</li>
</ul>
</aside>
</div>
</section>

<!-- 레이어 - 실시간 -->
<aside class="layer layer-select realtime" style="top: 165px;left: 600px;display:block;visibility:hidden;">
<div class="box-shadow"></div>
<h1>선택 레이어</h1>

<div class="innerScroll">
<ul class="list-layer-select center">
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=12" class="hyrend">12:00</a></li>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=11" class="hyrend">11:00</a></li>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=10" class="hyrend">10:00</a></li>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=09" class="hyrend">09:00</a></li>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=08" class="hyrend">08:00</a></li>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=07" class="hyrend">07:00</a></li>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=01" class="hyrend">01:00</a></li>
<li><a href="https://music.bugs.co.kr/chart/track/realtime/total?chartdate=20251206&charthour=00" class="hyrend">00:00</a></li>

</ul>
</div>
</aside>
</article>


</div>

<div class="floatingTop">
<a href="javascript:void(bugs.navigator.scrollTop())" class="btnTop">TOP</a>
</div>

<script type="text/javascript" src="/js/jquery/jquery-dateFormat.min.js"></script>
<script>
$(window.document).ready(function() {
setTimeout(function(){
$.ajax({
url : g_urlAjax + "/board/notice/ajax/commonfooternotice",
type : "POST",
dataType : "json",
success : function(data){
if(data != null){
$("#commonFooterNotice a#commonFooterNoticeTitle").text(data.title);
$("#commonFooterNotice a#commonFooterNoticeTitle").attr("href", g_urlMusic + "/board/notice?srl=" + data.srl + "&wl_ref=M_footer_01_01");
$("#commonFooterNotice time").text(data.str_crt_dt);
$("#commonFooterNotice time").attr("datetime", $.format.date(Date.parse(data.str_crt_dt,"yyyy.MM.dd"), "yyyy-MM-dd"));
}
}
});
}, 1300);

});
</script>
<script type="text/javascript" src="/js/bugs/bugs.footer.layer.js"></script>
<footer id="footer" >
<section class="sectionPadding">
<div class="innerContainer">
<div class="notice" id="commonFooterNotice">
<strong><a href="https://music.bugs.co.kr/board/notice?wl_ref=M_footer_01_01">공지사항</a></strong>
<a href="javascript:;" id="commonFooterNoticeTitle"></a>
<time datetime=""></time>
</div>
<div class="quicklinks">
<ul>
<li><a href="https://music.bugs.co.kr/event?wl_ref=M_footer_02_01">이벤트</a></li>
<li><a href="https://music.bugs.co.kr/panel?wl_ref=M_footer_02_01">벅스패널</a></li>
</ul>
<ul>
<li><a href="https://music.bugs.co.kr/serviceGuide/home?wl_ref=M_footer_02_07">벅스 꿀팁 보기</a></li>
</ul>
</div>
</div>
</section>

<section class="sectionPadding contents">
<div class="innerContainer">
<ul class="links">
<li><a href="http://www.bugscorp.co.kr?wl_ref=M_footer_03_01" target="_blank">회사소개</a></li>
<li><a href="https://music.bugs.co.kr/cooperation?wl_ref=M_footer_03_01">제휴문의</a></li>
<li><a href="https://music.bugs.co.kr/rules/use?wl_ref=M_footer_03_01">이용약관</a></li>
<li><a href="https://music.bugs.co.kr/rules/privacy?wl_ref=M_footer_03_01"><em>개인정보처리방침</em></a></li>
<li><a href="https://music.bugs.co.kr/rules/youth?wl_ref=M_footer_03_01">청소년보호정책</a></li>
<li><a href="https://music.bugs.co.kr/connect/center?wl_ref=M_footer_03_01">커넥트 센터</a></li>
<li><a href="http://help.bugs.co.kr?wl_ref=M_footer_03_01">고객센터</a></li>
<li><a href="https://music.bugs.co.kr/sitemap?wl_ref=M_footer_03_01">사이트맵</a></li>
<li><a href="https://inside.nhn.com/br/index.nhn" target="_blank">NHN 브랜드 사이트</a></li>
</ul>

<aside>
<div class="sns">
<a href="https://x.com/bugs_official_" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank" class="twitter">트위터</a>
<a href="https://www.instagram.com/bugs.official_/" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank" class="instagram">인스타그램</a>
<a href="https://www.facebook.com/bugsplay" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank" class="facebook">페이스북</a>
</div>

<div class="familysite">
<button tabindex="0" onclick="bugs.ui.cp.footerFamilySiteMenu(this);">FAMILY SITE</button>
<aside class="layer familysiteMenu">
<div class="box-shadow"></div>
<ul class="list-layer-select">
<li><a href="http://www.nhn.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">NHN</a></li>
<li><a href="http://me.sayclub.com" onclick="if(bugs.wiselog.area) {bugs.wiselog.area('M_fotter_03_01');}" target="_blank">세이클럽</a></li>
</ul>
</aside>
</div>
</aside>

<address>
<span>(주)엔에이치엔벅스</span>
<span>06043 서울특별시 강남구 강남대로 586, 제이빌딩</span>
<span>대표이사 : 왕문주</span>
<span>고객센터 : <a href="mailto:help@help.bugs.co.kr">help@help.bugs.co.kr</a> / 1566-4882 (유료)</span><br />
<span>사업자등록번호 : 211-87-15555</span>
<span>통신판매업 신고번호 : 제2023-강남-04353호</span>
<span>호스팅 제공자 : (주)엔에이치엔벅스</span>
<span><a href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2118715555" target="_blank">사업자 정보 확인</a></span>
<span>© NHN Bugs Corp. All rights reserved.</span>
</address>

<script>

if (!bugs.ui.cp) {
bugs.ui.cp = {
headerGameMenuToggle : function() {
$('.layer.gameMenu').toggle();

if(bugs.wiselog.area) {
bugs.wiselog.area('M_header_02_02');
}
},
footerFamilySiteMenu : function() {
$('.layer.familysiteMenu').toggle();

if(bugs.wiselog.area) {
bugs.wiselog.area('M_fotter_03_01');
}
}
};
}

</script>

<ul class="emblem">
<li>
<a href="https://help.bugs.co.kr/hc/notice/2586/" target="_blank" onclick="bugs.wiselog.area('M_fotter_03_01');">
<img src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemGooglePlay.png" alt="Google Play 선정 2018 올해를 빛낸 앱" loading="lazy" />
</a>
</li>
<li>
<a href="https://music.bugs.co.kr/specialView/supersound/NJ6P8GAP0ERQFD84GUCF" onclick="bugs.wiselog.area('M_fotter_03_01');">
<img src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHiRes.png" alt="하이 레졸루션 공식인증" loading="lazy" />
</a>
</li>
<li>
<a href="https://help.bugs.co.kr/hc/notice/1933/" target="_blank" onclick="bugs.wiselog.area('M_fotter_03_01');">
<img src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemHerald.png" alt="2015 상반기 대학생선호브랜드 대상" loading="lazy" />
</a>
</li>
<li>
<a href="https://help.bugs.co.kr/hc/notice/1522/" target="_blank" onclick="bugs.wiselog.area('M_fotter_03_01');">
<img src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemAppaward.png" alt="스마트앱어워드 대상 수상" loading="lazy" />
</a>
</li>
<li>
<button onclick="bugs.footer.layer.showIsms();">
<img src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemISMSV202108.png" alt="정보보호 관리체계 ISMS 인증" loading="lazy" />
</button>
</li>
<li>
<img src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemClms.png" alt="음악저작권 이용 허락 인증" loading="lazy" />
</li>
<li>
<a href="https://www.kcopa.or.kr/lay1/S1T356C360/contents.do" onclick="bugs.wiselog.area('M_fotter_03_01');" target="_blank">
<img src="https://file.bugsm.co.kr/wbugs/common/footer/i_footerEmblemCopyrightokV20220803.png" alt="저작권안심" loading="lazy" />
</a>
</li>
</ul>
</div>
</section>
</footer>

</div>
<!--<a href="javascript:void(playlists.resetPlaylist())">리셋하기</a>-->
<script type="text/javascript">
$(document).ready(function(){
try{
bugs.navigator.addHyrendUnloadHandler(function(){playlists.playlistLayerHide();},"track2playlistForMoveHyrend", true);
}catch(e){}

});
</script>
<aside id="track2playlist" class="layer layer-select addMyAlbum" style="display:none;">
<div class="box-shadow"></div>
<h1>내 앨범 목록</h1>
<div class="innerScroll" autoScroll="N" id="track2playlistScrollArea">
<ul class="list-layer-select">
<li><a href="javascript:;" onclick="$('#track2playlist').hide('blind', {}, 'normal', function() { bugs.ui.modalLayer.hide();playlists.make(); });" title="새 앨범 만들기">+ 새 앨범 만들기</a></li>
</ul>
</div>
</aside>

<!-- 레이어 - 내 앨범 수정 -->
<aside id="editMyAlbumLayer" class="layer createMyAlbum" style="display:none; z-index:1002;">
<div class="box-shadow"></div>

<header class="layer-title">
<h1>앨범 정보 수정</h1>
</header>

<section class="layerContents">

<fieldset>
<legend>내 앨범 수정</legend>

<table class="formLayout">
<caption>내 앨범 수정 입력 폼</caption>
<tbody>
<tr>
<th scope="row"><label for="editMyAlbumLayerPhoto" class="lb">사진</label></th>
<td>
<img src="https://file.bugsm.co.kr/wbugs/common/i_defaultMyAlbum_50x50.png" id="editMyAlbumLayerPhoto_img" alt="" class="thumb">
<div class="inputFile">
<input type="text" id="editMyAlbumLayerPhoto" class="file" diabled />
<button class="btnNormal" type="button" id="searchImage">찾아보기</button>
<input type="hidden" id="editMyAlbumLayerPhoto_path" title="사진경로" />
</div>
</td>
<td class="right" style="width:55px;"></td>
</tr>
<tr>
<th scope="row" style="width:55px;"><label for="editMyAlbumLayerTitle" class="lb">제목</label></th>
<td><input type="text" id="editMyAlbumLayerTitle" class="txt" value="111"></td>
<td class="right" style="width:55px;"><span class="remain" id="editMyAlbumLayerTitleRemain">(0/100)</span></td>
</tr>
<tr>
<th scope="row"><label for="editMyAlbumLayerDescribe" class="lb">설명</label></th>
<td>
<textarea name="" id="editMyAlbumLayerDescribe" cols="30" rows="10" class="txtArea"></textarea>
</td>
<td class="right"><span class="remain" id="editMyAlbumLayerDescribeRemain">(0/300)</span></td>
</tr>
</tbody>
</table>

<p class="btns">
<button id="editMyAlbumLayerUpdate" btnType="ok" class="btnNormal">저장</button>
<button id="editMyAlbumLayerCancel" btnType="cancel" class="btnNormal">취소</button>
</p>
</fieldset>

</section>
<button class="btnClose" btnType="close" id="editMyAlbumLayerClose">닫기</button>
</aside>


<aside id="createMyAlbumLayer" class="layer createMyAlbum" style="display:none; z-index:1000;">
<div class="box-shadow"></div>

<header class="layer-title">
<h1 id="createMyAlbumLayerHeader"></h1>
</header>

<section class="layerContents">

<fieldset>
<legend id="createMyAlbumLayerLegend"></legend>

<div class="row">
<label for="createMyAlbumLayerTitle">제목</label>
<div class="col">
<input type="text" id="createMyAlbumLayerTitle" class="txt" value="">
<span class="remain" id="createMyAlbumLayerTitleRemain">(0/100)</span>
</div>
</div>

<div class="btns">
<button id="createMyAlbumLayerUpdate" btnType="ok" class="btnNormal strong">저장</button>
<button id="createMyAlbumLayerCancel" btnType="cancel" class="btnNormal">취소</button>
</div>
</fieldset>

</section>
<button class="btnClose" btnType="close" id="crerateMyAlbumLayerClose">닫기</button>
</aside>
<span id="removeSpecialCharTarget" style="display:none;"></span>
<script>
try{
bugs.navigator.setLeftMenuShowOnLoad();
}
catch(e){}
$(document).ready(function(){
var isFirefox = navigator.userAgent.toLowerCase().indexOf('firefox') > -1;
if(isFirefox){
$("#skipNav").css({top:"1px", left:"1px"});
}
});
</script>

<!-- 470517 -->
<script>
try {
var expTime = (new Date()).getTime() + (60*60*24*30*1000);
var expTime2 = (new Date()).getTime() - (60*5*1000);
bugs.cookie.set("last_login_log_date_cookie","", expTime2, "/", "bugs.co.kr");
}
catch(e){}
</script>
<!-- 공통 적용 스크립트 , 모든 페이지에 노출되도록 설치. 단 전환페이지 설정값보다 항상 하단에 위치해야함 -->

<script type="text/javascript" src="//wcs.naver.net/wcslog.js"> </script>
<script type="text/javascript">
if (!wcs_add) var wcs_add={};
wcs_add["wa"] = "s_595467f7a42";
if (!_nasa) var _nasa={};
wcs.inflow("bugs.co.kr");
wcs_do(_nasa);
</script>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <html><body><p>자동 줄바꿈
# <!DOCTYPE html>
#
# </p>
# <!-- bgsweb-www908 -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="노래추천, 음악추천, 플레이리스트, essential, 에센셜, 스트리밍, 스밍, 뮤직PD, 노래듣기, 음악다운로드, 페이코" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script type="text/javascript">
# if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0
# || location.href.indexOf("help.bugs.co.kr") >= 0))
# document.domain = 'bugs.co.kr';
#
# var g_urlBase = "https://www.bugs.co.kr";
# var g_urlWww = "https://www.bugs.co.kr";
# var g_urlSecure = "https://secure.bugs.co.kr";
# var g_urlMusic = "https://music.bugs.co.kr";
# var g_urlMusicSecure = "https://music.bugs.co.kr";
# var g_urlMember = "https://secure.bugs.co.kr/member";
# var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# ...

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    자동 줄바꿈
#    <!DOCTYPE html>
#   </p>
#   <!-- bgsweb-www908 -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="노래추천, 음악추천, 플레이리스트, essential, 에센셜, 스트리밍, 스밍, 뮤직PD, 노래듣기, 음악다운로드, 페이코" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script type="text/javascript">
#    if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0
# || location.href.indexOf("help.bugs.co.kr") >= 0))
# document.domain = 'bugs.co.kr';
#
# var g_urlBase = "https://www.bugs.co.kr";
# var g_urlWww = "https://www.bugs.co.kr";
# var g_urlSecure = "https://secure.bugs.co.kr";
# var g_urlMusic = "https://music.bugs.co.kr";
# var g_urlMusicSecure = "https://music.bugs.co.kr";
# var g_urlMember = "https://secure.bugs.co.kr/member";
# ...

# %%
titles = soup.select('p.title')
artists = soup.select('p.artist')

# for titles, artists in zip(t_titles, t_artists):
#     titles = titles.strip()
#     artists = artists.strip()
music = []
name = []

for title, artist in zip(titles, artists):
    name.append(artist.text.strip())
    music.append(title.text.strip())
# import pandas as pd
len(music)

import pandas as pd
bugs = pd.DataFrame({"b_title": music,
                    'b_artist': name})
bugs.index = [f'{i}위' for i in range(1,101)]

bugs.index.name = '순위'

# %%
bugs
# Out:
#                               b_title  \
# 순위
# 1위                       Good Goodbye
# 2위                      ONE MORE TIME
# 3위                             Golden
# 4위    SPAGHETTI (feat. j-hope of BTS)
# 5위                     Blue Valentine
# ...                               ...
# 96위                     Love wins all
# 97위                            Flower
# 98위                             네모의 꿈
# 99위                              DRIP
# 100위                        Attention
#
#                                         b_artist
# 순위
# 1위                                    화사 (HWASA)
# 2위                                ALLDAY PROJECT
# 3위                          HUNTR/X\n\n\nHUNTR/X
# 4위    LE SSERAFIM (르세라핌)\n\n\nLE SSERAFIM (르세라핌)
# 5위                                         NMIXX
# ...                                          ...
# 96위                                      아이유(IU)
# 97위                                     오반(OVAN)
# ...

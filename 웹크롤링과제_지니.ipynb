# %%
from bs4 import BeautifulSoup

# %%
from fake_useragent import UserAgent
import requests

# %%
url = 'https://www.genie.co.kr/chart/top200'

# %%
ua = UserAgent()

# %%
# 헤더 선언
headers = {
'User-Agent': ua.chrome,
'referer': 'https://naver.com'
}

# %%
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <head>
#  <title>
#   지니
#  </title>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="//image.genie.co.kr/imageg/mobile_web/common/favicon.png" rel="apple-touch-icon-precomposed"/>
#  <link href="//image.genie.co.kr/imageg/mobile_web/common/favicon.ico" rel="shortcut icon"/>
#  <meta content="국내 최다 음원 보유, FLAC 고음질, 지니차트, 최신음악, 앨범, 뮤직비디오, 오늘의 선곡, TV속음악, 시대별음악, 지니라이프 등 제공" name="description">
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta content="-1" http-equiv="Expires"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://image.genie.co.kr" property="og:image">
#    <meta content="https://image.genie.co.kr" property="og:image:secure_url">
#     <meta content="" property="og:title">
#      <meta content="음악, 그리고 설레임 - 지니" property="og:description">
# ...

# %%
titles = soup.findAll('p', {'class':'track ellipsis'})
artists = soup.select('span.artist')

# %%
# 확인 
# artists

# %%
# for artist in artists:
#     print(artist.text)

# %%
musics = []
names = []

for title, artist in zip(titles, artists):
    musics.append(title.get_text().strip())
    names.append(artist.text.strip())

# %%
import pandas as pd

genie = pd.DataFrame({'Service':'Genie','title':musics,
                      'artist':names})

genie.index = [f'{i}위' for i in range(1,51)]

genie.index.name = '순위'

genie
# Out:
#     Service                            title  \
# 순위
# 1위    Genie                     Good Goodbye
# 2위    Genie                             타임캡슐
# 3위    Genie                           Golden
# 4위    Genie                    ONE MORE TIME
# 5위    Genie                   Blue Valentine
# 6위    Genie                         Drowning
# 7위    Genie                           멸종위기사랑
# 8위    Genie                         뛰어(JUMP)
# 9위    Genie                         Soda Pop
# 10위   Genie                     달리 표현할 수 없어요
# 11위   Genie  SPAGHETTI (Feat. j-hope of BTS)
# 12위   Genie                           FAMOUS
# 13위   Genie  All I Want for Christmas Is You
# 14위   Genie            모르시나요 (Prod. by 로코베리)
# 15위   Genie                           시작의 아이
# 16위   Genie                       어제보다 슬픈 오늘
# 17위   Genie                 내게 사랑이 뭐냐고 물어본다면
# 18위   Genie                        사랑은 늘 도망가
# 19위   Genie      힙합보단 사랑, 사랑보단 돈 (Feat. 베이식)
# 20위   Genie                          너에게 닿기를
# ...
